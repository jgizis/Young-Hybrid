# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from astropy.io import ascii

# %%
dirname='/Users/gizis/data/Models/CELLO'

# %%
#Set up the hot start model names
hname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
# have some extra at finer mass scales:
hname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
#

# %%
#  Read the Hot Start Models
model030hot=ascii.read(hname030)
model025hot=ascii.read(hname025)
model020hot=ascii.read(hname020)
model019hot=ascii.read(hname019)
model018hot=ascii.read(hname018)
model017hot=ascii.read(hname017)
model016hot=ascii.read(hname016)
model015hot=ascii.read(hname015)
model014hot=ascii.read(hname014)
model013hot=ascii.read(hname013)
model012hot=ascii.read(hname012)
model011hot=ascii.read(hname011)
model010hot=ascii.read(hname010)
model009hot=ascii.read(hname009)
model008hot=ascii.read(hname008)
model007hot=ascii.read(hname007)
model006hot=ascii.read(hname006)
model005hot=ascii.read(hname005)
model004hot=ascii.read(hname004)
model003hot=ascii.read(hname003)
model002hot=ascii.read(hname002)
model001hot=ascii.read(hname001)
#
model0155hot=ascii.read(hname0155)
model0145hot=ascii.read(hname0145)
model0135hot=ascii.read(hname0135)
model0125hot=ascii.read(hname0125)

# %%
#Set up the warm start model names
wname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
wname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
# have some extra at finer mass scales:
wname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
wname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
wname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
wname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_warmstart_stru.txt'.format(dirname,'Warm_Start_evolution_models')
#

# %%
#  Read the Warm Start Models
model030warm=ascii.read(wname030)
model025warm=ascii.read(wname025)
model020warm=ascii.read(wname020)
model019warm=ascii.read(wname019)
model018warm=ascii.read(wname018)
model017warm=ascii.read(wname017)
model016warm=ascii.read(wname016)
model015warm=ascii.read(wname015)
model014warm=ascii.read(wname014)
model013warm=ascii.read(wname013)
model012warm=ascii.read(wname012)
model011warm=ascii.read(wname011)
model010warm=ascii.read(wname010)
model009warm=ascii.read(wname009)
model008warm=ascii.read(wname008)
model007warm=ascii.read(wname007)
model006warm=ascii.read(wname006)
model005warm=ascii.read(wname005)
model004warm=ascii.read(wname004)
model003warm=ascii.read(wname003)
model002warm=ascii.read(wname002)
model001warm=ascii.read(wname001)
#
model0155warm=ascii.read(wname0155)
model0145warm=ascii.read(wname0145)
model0135warm=ascii.read(wname0135)
model0125warm=ascii.read(wname0125)

# %%
#Set up the cool start model names
cname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
# have some extra at finer mass scales:
cname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
#

# %%
#  Read the Cool Start Models
model030cool=ascii.read(cname030)
model025cool=ascii.read(cname025)
model020cool=ascii.read(cname020)
model019cool=ascii.read(cname019)
model018cool=ascii.read(cname018)
model017cool=ascii.read(cname017)
model016cool=ascii.read(cname016)
model015cool=ascii.read(cname015)
model014cool=ascii.read(cname014)
model013cool=ascii.read(cname013)
model012cool=ascii.read(cname012)
model011cool=ascii.read(cname011)
model010cool=ascii.read(cname010)
model009cool=ascii.read(cname009)
model008cool=ascii.read(cname008)
model007cool=ascii.read(cname007)
model006cool=ascii.read(cname006)
model005cool=ascii.read(cname005)
model004cool=ascii.read(cname004)
model003cool=ascii.read(cname003)
model002cool=ascii.read(cname002)
model001cool=ascii.read(cname001)
#
model0155cool=ascii.read(cname0155)
model0145cool=ascii.read(cname0145)
model0135cool=ascii.read(cname0135)
model0125cool=ascii.read(cname0125)

# %%
#Set up the ultracold start model names
uname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
# have some extra at finer mass scales:
uname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')

# %%
model015ucold=ascii.read(uname015)
model014ucold=ascii.read(uname014)
model013ucold=ascii.read(uname013)
model012ucold=ascii.read(uname012)
model011ucold=ascii.read(uname011)
model010ucold=ascii.read(uname010)
model009ucold=ascii.read(uname009)
model008ucold=ascii.read(uname008)
model007ucold=ascii.read(uname007)
model006ucold=ascii.read(uname006)
model005ucold=ascii.read(uname005)
model004ucold=ascii.read(uname004)
model003ucold=ascii.read(uname003)
model002ucold=ascii.read(uname002)
model001ucold=ascii.read(uname001)
model0125ucold=ascii.read(uname0125)

# %%
model025hot
# Out:
# <Table length=522>
#  col1     col2           col3           col4    col5    col6     col7     col8    col9  ...  col19    col20    col21   col22   col23      col24      col25   col26   col27
# int64   float64        float64        float64   str1  float64  float64  float64 float64 ... float64  float64  float64 float64 float64    float64    float64 float64 float64
# ----- ----------- ------------------ ---------- ---- --------- -------- ------- ------- ... ------- --------- ------- ------- ------- ------------- ------- ------- -------
#     0       100.0                0.0 -7.231e-12    r 2.911e-37 -1.47873 5.10057 0.70801 ...     0.0    0.5196    5.43     7.5     0.0 1.7651636e-06   0.275 0.19785  2.1111
#     1       100.0              100.0 -6.782e-12    r 2.661e-37 -1.46533 5.10407 0.70801 ...     0.0    0.4937    5.49     7.6     0.0 1.7651673e-06   0.275 0.19889  2.1224
# ...

# %%
plt.plot(10.0**model030hot['col11'],model030hot['col12'],label='0.030')
plt.plot(10.0**model025hot['col11'],model025hot['col12'],label='0.025')
plt.plot(10.0**model020hot['col11'],model020hot['col12'],label='0.020')
plt.plot(10.0**model015hot['col11'],model015hot['col12'],label='0.015')
plt.plot(10.0**model012hot['col11'],model012hot['col12'],label='0.012')
plt.plot(10.0**model010hot['col11'],model010hot['col12'],label='0.010')
plt.plot(10.0**model008hot['col11'],model008hot['col12'],label='0.008')
plt.plot(10.0**model005hot['col11'],model005hot['col12'],label='0.005')
plt.plot(10.0**model003hot['col11'],model003hot['col12'],label='0.003')
plt.plot(10.0**model001hot['col11'],model001hot['col12'],label='0.001')
plt.xlim(2200,400)
plt.xlabel('Temperature (K)')
plt.ylabel('log Luminosity (solar)')
plt.legend()
plt.title('Hot Start')
#HR diagram looks conventional on this scale although there is a feature at ~1100-1200K
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030hot['col3']/1e6,model030hot['col12'],label='0.030')
plt.plot(model025hot['col3']/1e6,model025hot['col12'],label='0.025')
plt.plot(model020hot['col3']/1e6,model020hot['col12'],label='0.020')
plt.plot(model015hot['col3']/1e6,model015hot['col12'],label='0.015')
plt.plot(model014hot['col3']/1e6,model014hot['col12'],label='0.014')
plt.plot(model013hot['col3']/1e6,model013hot['col12'],label='0.013')
plt.plot(model012hot['col3']/1e6,model012hot['col12'],label='0.012')
plt.plot(model011hot['col3']/1e6,model011hot['col12'],label='0.011')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],label='0.010')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],label='0.008')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'--',label='0.005')
plt.plot(model003hot['col3']/1e6,model003hot['col12'],'--',label='0.003')
plt.xlim(20,300)
plt.ylim(-6,-2)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030hot['col3']/1e6,10**model030hot['col11'],label='0.030')
plt.plot(model025hot['col3']/1e6,10**model025hot['col11'],label='0.025')
plt.plot(model020hot['col3']/1e6,10**model020hot['col11'],label='0.020')
plt.plot(model016hot['col3']/1e6,10**model016hot['col11'],label='0.016')
plt.plot(model015hot['col3']/1e6,10**model015hot['col11'],label='0.015')
plt.plot(model014hot['col3']/1e6,10**model014hot['col11'],label='0.014')
plt.plot(model0135hot['col3']/1e6,10**model0135hot['col11'],label='0.0135')
plt.plot(model013hot['col3']/1e6,10**model013hot['col11'],label='0.013')
plt.plot(model0125hot['col3']/1e6,10**model0125hot['col11'],label='0.0125')
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],label='0.012')
plt.plot(model011hot['col3']/1e6,10**model011hot['col11'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],'--',label='0.010')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],'--',label='0.008')
plt.plot(model005hot['col3']/1e6,10**model005hot['col11'],'--',label='0.005')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],'--',label='0.003')
plt.xlim(5,300)
plt.ylim(800,2600)
plt.legend(ncol=2)
plt.xlabel('Age (yr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030warm['col3']/1e6,10**model030warm['col11'],label='0.030')
plt.plot(model025warm['col3']/1e6,10**model025warm['col11'],label='0.025')
plt.plot(model020warm['col3']/1e6,10**model020warm['col11'],label='0.020')
plt.plot(model015warm['col3']/1e6,10**model015warm['col11'],label='0.015')
plt.plot(model014warm['col3']/1e6,10**model014warm['col11'],label='0.014')
plt.plot(model0135warm['col3']/1e6,10**model0135warm['col11'],label='0.0135')
plt.plot(model013warm['col3']/1e6,10**model013warm['col11'],label='0.013')
plt.plot(model0125warm['col3']/1e6,10**model0125warm['col11'],label='0.0125')
plt.plot(model012warm['col3']/1e6,10**model012warm['col11'],label='0.012')
plt.plot(model011warm['col3']/1e6,10**model011warm['col11'],'--',label='0.011')
plt.plot(model010warm['col3']/1e6,10**model010warm['col11'],'--',label='0.010')
plt.plot(model008warm['col3']/1e6,10**model008warm['col11'],'--',label='0.008')
plt.plot(model005warm['col3']/1e6,10**model005warm['col11'],'--',label='0.005')
plt.plot(model003warm['col3']/1e6,10**model003warm['col11'],'--',label='0.003')
plt.xlim(5,300)
plt.ylim(800,2600)
plt.legend(ncol=2)
plt.xlabel('Age (yr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Warm Start')
# Out:
# Text(0.5, 1.0, 'Warm Start')

# %% [markdown]
# The dramatic results for Teff as a function of age for young moving groups and clusters. Need to think about it!

# %%
plt.plot(model030hot['col3']/1e6,10**model030hot['col10'],label='0.030')
plt.plot(model025hot['col3']/1e6,10**model025hot['col10'],label='0.025')
plt.plot(model020hot['col3']/1e6,10**model020hot['col10'],label='0.020')
plt.plot(model015hot['col3']/1e6,10**model015hot['col10'],label='0.015')
plt.plot(model014hot['col3']/1e6,10**model014hot['col10'],label='0.014')
plt.plot(model0135hot['col3']/1e6,10**model0135hot['col10'],label='0.0135')
plt.plot(model013hot['col3']/1e6,10**model013hot['col10'],label='0.013')
plt.plot(model0125hot['col3']/1e6,10**model0125hot['col10'],label='0.0125')
plt.plot(model012hot['col3']/1e6,10**model012hot['col10'],label='0.012')
plt.plot(model011hot['col3']/1e6,10**model011hot['col10'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,10**model010hot['col10'],'--',label='0.010')
plt.plot(model008hot['col3']/1e6,10**model008hot['col10'],'--',label='0.008')
plt.xlim(.1,50)
plt.ylim(0.05,0.3)
plt.legend(ncol=2)
plt.xlabel('Age (yr)')
plt.ylabel('Radius ($R_\odot$)')
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030hot['col3']/1e9,10**model030hot['col10'],label='0.030')
plt.plot(model025hot['col3']/1e9,10**model025hot['col10'],label='0.025')
plt.plot(model020hot['col3']/1e9,10**model020hot['col10'],label='0.020')
plt.plot(model015hot['col3']/1e9,10**model015hot['col10'],label='0.015')
plt.plot(model012hot['col3']/1e9,10**model012hot['col10'],label='0.012')
plt.plot(model010hot['col3']/1e9,10**model010hot['col10'],label='0.010')
plt.plot(model008hot['col3']/1e9,10**model008hot['col10'],label='0.008')
plt.xlim(1,10)
plt.ylim(0,.2)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Radius $R_\odot$')
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030hot['col3']/1e9,10**model030hot['col11'],label='0.030')
plt.plot(model025hot['col3']/1e9,10**model025hot['col11'],label='0.025')
plt.plot(model020hot['col3']/1e9,10**model020hot['col11'],label='0.020')
plt.plot(model015hot['col3']/1e9,10**model015hot['col11'],label='0.015')
plt.plot(model012hot['col3']/1e9,10**model012hot['col11'],label='0.012')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='0.010')
plt.plot(model008hot['col3']/1e9,10**model008hot['col11'],label='0.008')
plt.plot(model005hot['col3']/1e9,10**model005hot['col11'],label='0.005')
#Note: overplotting warm models shows they are effectively the same at old ages
#   uncomment to see for yourself
#plt.plot(model030warm['col3']/1e9,10**model030warm['col11'],'-.',label='0.030')
#plt.plot(model010warm['col3']/1e9,10**model010warm['col11'],'-.',label='0.010')
plt.xlim(1,10)
plt.ylim(300,900)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %% [markdown]
# At old ages, models are well behaved as we produce late-T and Y dwarfs.

# %%
plt.plot(model030hot['col3']/1e9,model030hot['col12'],label='0.030')
plt.plot(model025hot['col3']/1e9,model025hot['col12'],label='0.025')
plt.plot(model020hot['col3']/1e9,model020hot['col12'],label='0.020')
plt.plot(model015hot['col3']/1e9,model015hot['col12'],label='0.015')
plt.plot(model012hot['col3']/1e9,model012hot['col12'],label='0.012')
plt.plot(model010hot['col3']/1e9,model010hot['col12'],label='0.010')
plt.plot(model008hot['col3']/1e9,model008hot['col12'],label='0.008')
plt.plot(model005hot['col3']/1e9,model005hot['col12'],label='0.005')
plt.plot(model003hot['col3']/1e9,model003hot['col12'],label='0.003')
plt.xlim(1,10)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7.5,-4.5)
plt.title('Hot Start')
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %% [markdown]
# At old ages, everything is well behaved.  These are Y dwarfs.

# %%
plt.plot(model030hot['col3']/1e6,model030hot['col12'],label='0.030')
plt.plot(model025hot['col3']/1e6,model025hot['col12'],label='0.025')
plt.plot(model020hot['col3']/1e6,model020hot['col12'],label='0.020')
plt.plot(model015hot['col3']/1e6,model015hot['col12'],label='0.015')
plt.plot(model014hot['col3']/1e6,model014hot['col12'],label='0.014')
plt.plot(model013hot['col3']/1e6,model013hot['col12'],label='0.013')
plt.plot(model012hot['col3']/1e6,model012hot['col12'],label='0.012')
plt.plot(model011hot['col3']/1e6,model011hot['col11'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'--',label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'--',label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'--',label='0.008')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'--',label='0.005')
plt.xlim(10,200)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
# Out:
# (-5.5, -2.0)

# %% [markdown]
# Above we see the relevant ages (beta Pic ~23 Myr; AB Dor/Pleiades ~120 Myr; etc.).   Hot Start only.

# %%
plt.plot(10.0**model030hot['col11'],model030hot['col27'],label='0.030')
plt.plot(10.0**model025hot['col11'],model025hot['col27'],label='0.025')
plt.plot(10.0**model020hot['col11'],model020hot['col27'],label='0.020')
plt.plot(10.0**model015hot['col11'],model015hot['col27'],label='0.015')
plt.plot(10.0**model012hot['col11'],model012hot['col27'],label='0.012')
plt.plot(10.0**model010hot['col11'],model010hot['col27'],label='0.010')
plt.plot(10.0**model008hot['col11'],model008hot['col27'],label='0.008')
plt.plot(10.0**model005hot['col11'],model005hot['col27'],label='0.005')
plt.plot(10.0**model003hot['col11'],model003hot['col27'],label='0.003')
plt.plot(10.0**model001hot['col11'],model001hot['col27'],label='0.001')
plt.xlim(2200,400)
plt.xlabel('Temperature (K)')
plt.ylabel('log g')
plt.legend(ncol=2)
plt.title('Hot Start')
#arguably log g <~4.5 for cooler L/T transition temperature
# Out:
# Text(0.5, 1.0, 'Hot Start')

# %%
plt.plot(model030hot['col3']/1e6,model030hot['col27'],label='0.030')
plt.plot(model025hot['col3']/1e6,model025hot['col27'],label='0.025')
plt.plot(model020hot['col3']/1e6,model020hot['col27'],label='0.020')
plt.plot(model015hot['col3']/1e6,model015hot['col27'],label='0.015')
plt.plot(model012hot['col3']/1e6,model012hot['col27'],label='0.012')
plt.plot(model010hot['col3']/1e6,model010hot['col27'],label='0.010')
plt.plot(model008hot['col3']/1e6,model008hot['col27'],label='0.008')
plt.plot(model003hot['col3']/1e6,model003hot['col27'],label='0.003')
plt.xlim(10,100)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('log g (cgs)')
# Out:
# Text(0, 0.5, 'log g (cgs)')

# %%
#Let's also consider Bobcat Solar metallicity models
bobcat = ascii.read("/Users/gizis/book/BrownDwarfBook/data/Sonora_Bobcat_nc+0.0_co1.0_mass.my.txt")
#Let us try Saumon & Marley 2009 "Hybrid" models
hybrid = ascii.read("/Users/gizis/book/BrownDwarfBook/data/hybrid_solar_age.txt") 
#

# %%
i_h_m010 = (hybrid["M/Msun"] == 0.010)
i_b_m010 = (bobcat["M/Msun"] == 0.010)
i_h_m020 = (hybrid["M/Msun"] == 0.020)
i_b_m020 = (bobcat["M/Msun"] == 0.020)
i_h_m025 = (hybrid["M/Msun"] == 0.025)
i_b_m025 = (bobcat["M/Msun"] == 0.025)
i_h_m008 = (hybrid["M/Msun"] == 0.008)
i_b_m008 = (bobcat["M/Msun"] == 0.008)
i_h_m012 = (hybrid["M/Msun"] == 0.012)
i_b_m012 = (bobcat["M/Msun"] == 0.012)

# %%
bobcat[i_b_m010]
# Out:
# <Table length=29>
#  M/Msun age(Gyr) log_L/Lsun Teff(K)  log_g   R/Rsun
# float64 float64   float64   float64 float64 float64
# ------- -------- ---------- ------- ------- -------
#    0.01    0.001     -2.729  2368.0    3.62  0.2563
#    0.01    0.002     -2.989  2234.0   3.778  0.2137
#    0.01    0.003     -3.159  2125.0   3.862  0.1941
#    0.01    0.004     -3.291  2035.0   3.918  0.1819
#    0.01    0.006     -3.481  1901.0   3.989  0.1676
#    0.01    0.008     -3.626  1794.0   4.034  0.1591
#    0.01     0.01     -3.746  1706.0   4.066  0.1534
#    0.01    0.015     -3.965  1546.0   4.114  0.1451
#     ...      ...        ...     ...     ...     ...
#    0.01      1.0     -6.263   474.0    4.36  0.1093
#    0.01      1.5     -6.466   425.0   4.371  0.1079
#    0.01      2.0     -6.619   391.0   4.379  0.1069
#    0.01      3.0     -6.792   356.0    4.39  0.1057
#    0.01      4.0     -6.911   334.0   4.397  0.1048
#    0.01      6.0     -7.086   304.0   4.408  0.1035
# ...

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='UD (Hot)')
plt.plot(model010cool['col3']/1e9,10**model010cool['col11'],label='UD (Cool)')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.010 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='CELLO (Hot)')
plt.plot(model010cool['col3']/1e9,10**model010cool['col11'],label='CELLO (Cool)')
plt.xlim(2,10)
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.ylim(200,400)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
print(1.02**4)
plt.title('Comparison: 0.010 $M_\odot$');
# Out:
# 1.08243216

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='CELLO')
plt.plot(model010cool['col3']/1e9,10**model010cool['col11'],label='CELLO (cool)')
plt.xlim(0.1,0.5)
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.ylim(500,1000)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
print(1.02**4)
plt.title('Comparison: 0.010 $M_\odot$');
# Out:
# 1.08243216

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m012],hybrid['Teff(K)'][i_h_m012],label='Hybrid')
plt.plot(model012hot['col3']/1e9,10**model012hot['col11'],label='UD')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.012 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['Teff(K)'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,10**model008hot['col11'],label='CELLO (Hot)')
plt.plot(model008cool['col3']/1e9,10**model008cool['col11'],label='CELLO (Cool)')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['Teff(K)'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,10**model008hot['col11'],label='CELLO (hot)')
plt.plot(model008cool['col3']/1e9,10**model008cool['col11'],label='CELLO (cool)')
plt.xlim(1,10)
plt.ylim(200,500)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['log_L/Lsun'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,model008hot['col12'],label='CELLO (Hot)')
plt.plot(model008cool['col3']/1e9,model008cool['col12'],label='CELLO (Cool)')
plt.plot(model008ucold['col3']/1e9,model008ucold['col12'],label='CELLO (Cold)')
plt.xlim(0.01,0.1)
plt.ylim(-6,-4)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(1.05),label='Bobcat+5%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(0.95),label='Bobcat-5%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('log Luminosity (solar)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['log_L/Lsun'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,model008hot['col12'],label='CELLO')
#plt.plot(model008cold['col3']/1e9,model008cold['col12'],label='UD (Cold)')
plt.xlim(1,10)
plt.ylim(-8,-4)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(1.05),label='Bobcat+5%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(0.95),label='Bobcat-5%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('log Luminosity (solar)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C5',label='0.012 hot')
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C0',label='0.010 hot')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],color='C1',label='0.008 hot')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],color='C2',label='0.003 hot')
plt.plot(model001hot['col3']/1e6,10**model001hot['col11'],color='C4',label='0.001 hot')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C5',label='0.012 cold',linestyle='--')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C0',label='0.010 cold',linestyle='--')
plt.plot(model008ucold['col3']/1e6,10**model008ucold['col11'],color='C1',label='0.008 cold',linestyle='--')
plt.plot(model003ucold['col3']/1e6,10**model003ucold['col11'],color='C2',label='0.003 cold',linestyle='--')
plt.plot(model001ucold['col3']/1e6,10**model001ucold['col11'],color='C4',label='0.001 cold',linestyle='--')
plt.xlim(1,40)
#plt.ylim(300,900)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %%
plt.plot(model010hot['col3']/1e6,10**model010hot['col10'],color='C0',label='0.010 hot')
plt.plot(model008hot['col3']/1e6,10**model008hot['col10'],color='C1',label='0.008 hot')
plt.plot(model003hot['col3']/1e6,10**model003hot['col10'],color='C2',label='0.003 hot')
plt.plot(model001hot['col3']/1e6,10**model001hot['col10'],color='C4',label='0.001 hot')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col10'],color='C0',label='0.010 cold',linestyle='--')
plt.plot(model008ucold['col3']/1e6,10**model008ucold['col10'],color='C1',label='0.008 cold',linestyle='--')
plt.plot(model003ucold['col3']/1e6,10**model003ucold['col10'],color='C2',label='0.003 cold',linestyle='--')
plt.plot(model001ucold['col3']/1e6,10**model001ucold['col10'],color='C4',label='0.001 cold',linestyle='--')
plt.xlim(5,30)
plt.ylim(0.1,0.20)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('Radius ($R_\odot$)')
# Out:
# Text(0, 0.5, 'Radius ($R_\\odot$)')

# %%
#Now consider some actual objects

# %%
age_vhs1256b = 140 #Myr
age_sigma_vhs1256b = 20
lum_vhs1256b = -4.55
lum_sigma_vhs1256b = 0.009
#
age_51erib = 24 #Myr
age_sigma_51erib = 3
lum_51erib = -5.5
lum_sigma_51erib = 0.2
#
age_aflepb = 24 #Myr
age_sigma_aflepb = 3
lum_aflepb = -5.23
lum_sigma_aflepb = 0.06

# %%
plt.plot(model030hot['col3']/1e6,model030hot['col12'],label='0.030')
plt.plot(model025hot['col3']/1e6,model025hot['col12'],label='0.025')
plt.plot(model020hot['col3']/1e6,model020hot['col12'],label='0.020')
plt.plot(model015hot['col3']/1e6,model015hot['col12'],label='0.015')
plt.plot(model014hot['col3']/1e6,model014hot['col12'],label='0.014')
plt.plot(model013hot['col3']/1e6,model013hot['col12'],label='0.013')
plt.plot(model012hot['col3']/1e6,model012hot['col12'],label='0.012')
plt.plot(model011hot['col3']/1e6,model011hot['col11'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'--',label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'--',label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'--',label='0.008')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'--',label='0.005')
plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='k')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k')
plt.xlim(10,200)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
# Out:
# (-5.5, -2.0)

# %%
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C6',label='0.012 hot')
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C0',label='0.010 hot')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],color='C1',label='0.008 hot')
plt.plot(model005hot['col3']/1e6,10**model005hot['col11'],color='C2',label='0.005 hot')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],color='C3',label='0.003 hot')
plt.plot(model001hot['col3']/1e6,10**model001hot['col11'],color='C4',label='0.001 hot')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C6',label='0.012 cold',linestyle='--')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C0',label='0.010 cold',linestyle='--')
plt.plot(model008ucold['col3']/1e6,10**model008ucold['col11'],color='C1',label='0.008 cold',linestyle='--')
plt.plot(model005ucold['col3']/1e6,10**model005ucold['col11'],color='C2',label='0.008 cold',linestyle='--')
plt.plot(model003ucold['col3']/1e6,10**model003ucold['col11'],color='C3',label='0.003 cold',linestyle='--')
plt.plot(model001ucold['col3']/1e6,10**model001ucold['col11'],color='C4',label='0.001 cold',linestyle='--')
plt.xlim(1,10)
#plt.ylim(300,900)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %%
#plt.plot(model030ucold['col3']/1e6,model030ucold['col12'],label='0.030')
#plt.plot(model025ucold['col3']/1e6,model025ucold['col12'],label='0.025')
#plt.plot(model020ucold['col3']/1e6,model020ucold['col12'],label='0.020')
plt.plot(model015ucold['col3']/1e6,model015ucold['col12'],label='0.015')
plt.plot(model014ucold['col3']/1e6,model014ucold['col12'],label='0.014')
plt.plot(model013ucold['col3']/1e6,model013ucold['col12'],label='0.013')
plt.plot(model0125ucold['col3']/1e6,model0125ucold['col12'],label='0.0125')
#plt.plot(model012ucold['col3']/1e6,model012ucold['col12'],label='0.012')
#plt.plot(model011ucold['col3']/1e6,model011ucold['col11'],'--',label='0.011')
#plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'--',label='0.010')
#plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'--',label='0.009')
#plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'--',label='0.008')
#plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'--',label='0.005')
plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
plt.xlim(10,200)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
plt.title("Cold Start")
#Note that the lower masses <0.0125 woudl be off the bottom of the chart.
# Out:
# Text(0.5, 1.0, 'Cold Start')

# %%
#plt.plot(model030cold['col3']/1e6,model030cold['col12'],label='0.030')
#plt.plot(model025cold['col3']/1e6,model025cold['col12'],label='0.025')
#plt.plot(model020cold['col3']/1e6,model020cold['col12'],label='0.020')
plt.plot(model015ucold['col3']/1e6,model015ucold['col12'],label='0.015')
plt.plot(model014ucold['col3']/1e6,model014ucold['col12'],label='0.014')
plt.plot(model013ucold['col3']/1e6,model013ucold['col12'],label='0.013')
plt.plot(model012ucold['col3']/1e6,model012ucold['col12'],label='0.012')
plt.plot(model011ucold['col3']/1e6,model011ucold['col11'],'--',label='0.011')
plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'--',label='0.010')
plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'--',label='0.009')
plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'--',label='0.008')
plt.plot(model007ucold['col3']/1e6,model007ucold['col12'],'--',label='0.007')
plt.plot(model006ucold['col3']/1e6,model006ucold['col12'],'--',label='0.006')
plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'--',label='0.005')
plt.plot(model004ucold['col3']/1e6,model004ucold['col12'],'--',label='0.004')
plt.plot(model003ucold['col3']/1e6,model003ucold['col12'],'--',label='0.003')
plt.plot(model002ucold['col3']/1e6,model002ucold['col12'],'--',label='0.002')
plt.plot(model001ucold['col3']/1e6,model001ucold['col12'],'--',label='0.001')
plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='gray',label='51 Eri b')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k',label='AF Lep b')
plt.xlim(0,30)
plt.legend(loc='lower left',ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7,-3)
plt.title("Cold Start")
# Out:
# Text(0.5, 1.0, 'Cold Start')

# %%
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'-',color="C0",label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'-',color="C1",label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'-',color="C2",label='0.008')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'-',color="C3",label='0.007')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'-',color="C4",label='0.006')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'-',color="C5",label='0.005')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'-',color="C6",label='0.004')
plt.plot(model003hot['col3']/1e6,model003hot['col12'],'-',color="C7",label='0.003')
plt.plot(model002hot['col3']/1e6,model002hot['col12'],'-',color="C8",label='0.002')
plt.plot(model001hot['col3']/1e6,model001hot['col12'],'-',color="C9",label='0.001')
#
plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'--',color="C0")
plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'--',color="C1")
plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'--',color="C2")
plt.plot(model007ucold['col3']/1e6,model007ucold['col12'],'--',color="C3")
plt.plot(model006ucold['col3']/1e6,model006ucold['col12'],'--',color="C4")
plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'--',color="C5")
plt.plot(model004ucold['col3']/1e6,model004ucold['col12'],'--',color="C6")
plt.plot(model003ucold['col3']/1e6,model003ucold['col12'],'--',color="C7")
plt.plot(model002ucold['col3']/1e6,model002ucold['col12'],'--',color="C8")
plt.plot(model001ucold['col3']/1e6,model001ucold['col12'],'--',color="C9")
#
plt.plot(model010warm['col3']/1e6,model010warm['col12'],'-.',color="C0")
plt.plot(model009warm['col3']/1e6,model009warm['col12'],'-.',color="C1")
plt.plot(model008warm['col3']/1e6,model008warm['col12'],'-.',color="C2")
plt.plot(model007warm['col3']/1e6,model007warm['col12'],'-.',color="C3")
plt.plot(model006warm['col3']/1e6,model006warm['col12'],'-.',color="C4")
plt.plot(model005warm['col3']/1e6,model005warm['col12'],'-.',color="C5")
plt.plot(model004warm['col3']/1e6,model004warm['col12'],'-.',color="C6")
plt.plot(model003warm['col3']/1e6,model003warm['col12'],'-.',color="C7")
plt.plot(model002warm['col3']/1e6,model002warm['col12'],'-.',color="C8")
plt.plot(model001warm['col3']/1e6,model001warm['col12'],'-.',color="C9")
#
#plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
#plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='k')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k')
plt.xlim(0.5,30)
plt.legend(loc='lower left',ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7,-3)
# Out:
# (-7.0, -3.0)

# %%
plt.plot(model010warm['col3']/1e6,model010warm['col12'],'-.',color="C0")
plt.plot(model009warm['col3']/1e6,model009warm['col12'],'-.',color="C1")
plt.plot(model008warm['col3']/1e6,model008warm['col12'],'-.',color="C2")
plt.plot(model007warm['col3']/1e6,model007warm['col12'],'-.',color="C3")
plt.plot(model006warm['col3']/1e6,model006warm['col12'],'-.',color="C4")
plt.plot(model005warm['col3']/1e6,model005warm['col12'],'-.',color="C5")
plt.plot(model004warm['col3']/1e6,model004warm['col12'],'-.',color="C6")
plt.plot(model003warm['col3']/1e6,model003warm['col12'],'-.',color="C7")
plt.plot(model002warm['col3']/1e6,model002warm['col12'],'-.',color="C8")
plt.plot(model001warm['col3']/1e6,model001warm['col12'],'-.',color="C9")
#
#plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
#plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='k')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k')
plt.xlim(0.5,25)
#plt.legend(loc='lower left',ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7,-3)
plt.title("Warm Start")
# Out:
# Text(0.5, 1.0, 'Warm Start')

# %%
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'-',color="C0",label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'-',color="C1",label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'-',color="C2",label='0.008')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'-',color="C3",label='0.007')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'-',color="C4",label='0.006')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'-',color="C5",label='0.005')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'-',color="C6",label='0.004')
plt.plot(model003hot['col3']/1e6,model003hot['col12'],'-',color="C7",label='0.003')
plt.plot(model002hot['col3']/1e6,model002hot['col12'],'-',color="C8",label='0.002')
plt.plot(model001hot['col3']/1e6,model001hot['col12'],'-',color="C9",label='0.001')
#
plt.plot(model010cool['col3']/1e6,model010cool['col12'],'--',color="C0")
plt.plot(model009cool['col3']/1e6,model009cool['col12'],'--',color="C1")
plt.plot(model008cool['col3']/1e6,model008cool['col12'],'--',color="C2")
plt.plot(model007cool['col3']/1e6,model007cool['col12'],'--',color="C3")
plt.plot(model006cool['col3']/1e6,model006cool['col12'],'--',color="C4")
plt.plot(model005cool['col3']/1e6,model005cool['col12'],'--',color="C5")
plt.plot(model004cool['col3']/1e6,model004cool['col12'],'--',color="C6")
plt.plot(model003cool['col3']/1e6,model003cool['col12'],'--',color="C7")
plt.plot(model002cool['col3']/1e6,model002cool['col12'],'--',color="C8")
plt.plot(model001cool['col3']/1e6,model001cool['col12'],'--',color="C9")
#
#plt.plot(model010warm['col3']/1e6,model010warm['col12'],'-.',color="C0")
#plt.plot(model009warm['col3']/1e6,model009warm['col12'],'-.',color="C1")
#plt.plot(model008warm['col3']/1e6,model008warm['col12'],'-.',color="C2")
#plt.plot(model007warm['col3']/1e6,model007warm['col12'],'-.',color="C3")
#plt.plot(model006warm['col3']/1e6,model006warm['col12'],'-.',color="C4")
#plt.plot(model005warm['col3']/1e6,model005warm['col12'],'-.',color="C5")
#plt.plot(model004warm['col3']/1e6,model004warm['col12'],'-.',color="C6")
#plt.plot(model003warm['col3']/1e6,model003warm['col12'],'-.',color="C7")
#plt.plot(model002warm['col3']/1e6,model002warm['col12'],'-.',color="C8")
#plt.plot(model001warm['col3']/1e6,model001warm['col12'],'-.',color="C9")
#
plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'-.',color="C0")
plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'-.',color="C1")
plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'-.',color="C2")
plt.plot(model007ucold['col3']/1e6,model007ucold['col12'],'-.',color="C3")
plt.plot(model006ucold['col3']/1e6,model006ucold['col12'],'-.',color="C4")
plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'-.',color="C5")
plt.plot(model004ucold['col3']/1e6,model004ucold['col12'],'-.',color="C6")
plt.plot(model003ucold['col3']/1e6,model003ucold['col12'],'-.',color="C7")
plt.plot(model002ucold['col3']/1e6,model002ucold['col12'],'-.',color="C8")
plt.plot(model001ucold['col3']/1e6,model001ucold['col12'],'-.',color="C9")
#
#plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
#plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='k')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k')
plt.xlim(0.5,25)
plt.legend(loc='lower left',ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7,-3)
# Out:
# (-7.0, -3.0)

# %%
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'-',color="C0",label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'-',color="C1",label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'-',color="C2",label='0.008')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'-',color="C3",label='0.007')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'-',color="C4",label='0.006')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'-',color="C5",label='0.005')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'-',color="C6",label='0.004')
plt.plot(model003hot['col3']/1e6,model003hot['col12'],'-',color="C7",label='0.003')
plt.plot(model002hot['col3']/1e6,model002hot['col12'],'-',color="C8",label='0.002')
plt.plot(model001hot['col3']/1e6,model001hot['col12'],'-',color="C9",label='0.001')
#
plt.plot(model010cool['col3']/1e6,model010cool['col12'],'--',color="C0")
plt.plot(model009cool['col3']/1e6,model009cool['col12'],'--',color="C1")
plt.plot(model008cool['col3']/1e6,model008cool['col12'],'--',color="C2")
plt.plot(model007cool['col3']/1e6,model007cool['col12'],'--',color="C3")
plt.plot(model006cool['col3']/1e6,model006cool['col12'],'--',color="C4")
plt.plot(model005cool['col3']/1e6,model005cool['col12'],'--',color="C5")
plt.plot(model004cool['col3']/1e6,model004cool['col12'],'--',color="C6")
plt.plot(model003cool['col3']/1e6,model003cool['col12'],'--',color="C7")
plt.plot(model002cool['col3']/1e6,model002cool['col12'],'--',color="C8")
plt.plot(model001cool['col3']/1e6,model001cool['col12'],'--',color="C9")
#
#plt.plot(model010warm['col3']/1e6,model010warm['col12'],'-.',color="C0")
#plt.plot(model009warm['col3']/1e6,model009warm['col12'],'-.',color="C1")
#plt.plot(model008warm['col3']/1e6,model008warm['col12'],'-.',color="C2")
#plt.plot(model007warm['col3']/1e6,model007warm['col12'],'-.',color="C3")
#plt.plot(model006warm['col3']/1e6,model006warm['col12'],'-.',color="C4")
#plt.plot(model005warm['col3']/1e6,model005warm['col12'],'-.',color="C5")
#plt.plot(model004warm['col3']/1e6,model004warm['col12'],'-.',color="C6")
#plt.plot(model003warm['col3']/1e6,model003warm['col12'],'-.',color="C7")
#plt.plot(model002warm['col3']/1e6,model002warm['col12'],'-.',color="C8")
#plt.plot(model001warm['col3']/1e6,model001warm['col12'],'-.',color="C9")
#
plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'-.',color="C0")
plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'-.',color="C1")
plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'-.',color="C2")
plt.plot(model007ucold['col3']/1e6,model007ucold['col12'],'-.',color="C3")
plt.plot(model006ucold['col3']/1e6,model006ucold['col12'],'-.',color="C4")
plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'-.',color="C5")
plt.plot(model004ucold['col3']/1e6,model004ucold['col12'],'-.',color="C6")
plt.plot(model003ucold['col3']/1e6,model003ucold['col12'],'-.',color="C7")
plt.plot(model002ucold['col3']/1e6,model002ucold['col12'],'-.',color="C8")
plt.plot(model001ucold['col3']/1e6,model001ucold['col12'],'-.',color="C9")
#
#plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
#plt.errorbar(age_51erib,lum_51erib,yerr=lum_sigma_51erib,xerr=age_sigma_51erib,color='k')
plt.errorbar(age_aflepb,lum_aflepb,yerr=lum_sigma_aflepb,xerr=age_sigma_aflepb,color='k')
plt.xlim(0.5,1000)
plt.legend(loc='lower left',ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7,-3)
# Out:
# (-7.0, -3.0)

# %%
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C5',label='0.012 hot')
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C0',label='0.010 hot')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],color='C1',label='0.008 hot')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],color='C2',label='0.003 hot')
plt.plot(model001hot['col3']/1e6,10**model001hot['col11'],color='C4',label='0.001 hot')
plt.plot(model012warm['col3']/1e6,10**model012warm['col11'],color='C5',label='0.012 warm',linestyle='dotted')
plt.plot(model010warm['col3']/1e6,10**model010warm['col11'],color='C0',label='0.010 warm',linestyle='dotted')
plt.plot(model008warm['col3']/1e6,10**model008warm['col11'],color='C1',label='0.008 warm',linestyle='dotted')
plt.plot(model003warm['col3']/1e6,10**model003warm['col11'],color='C2',label='0.003 warm',linestyle='dotted')
plt.plot(model001warm['col3']/1e6,10**model001warm['col11'],color='C4',label='0.001 warm',linestyle='dotted')
plt.plot(model012cool['col3']/1e6,10**model012cool['col11'],color='C5',label='0.012 cool',linestyle='--')
plt.plot(model010cool['col3']/1e6,10**model010cool['col11'],color='C0',label='0.010 cool',linestyle='--')
plt.plot(model008cool['col3']/1e6,10**model008cool['col11'],color='C1',label='0.008 cool',linestyle='--')
plt.plot(model003cool['col3']/1e6,10**model003cool['col11'],color='C2',label='0.003 cool',linestyle='--')
plt.plot(model001cool['col3']/1e6,10**model001cool['col11'],color='C4',label='0.001 cool',linestyle='--')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C5',label='0.012 ucold',linestyle='-.')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C0',label='0.010 ucold',linestyle='-.')
plt.plot(model008ucold['col3']/1e6,10**model008ucold['col11'],color='C1',label='0.008 ucold',linestyle='-.')
plt.plot(model003ucold['col3']/1e6,10**model003ucold['col11'],color='C2',label='0.003 ucold',linestyle='-.')
plt.plot(model001ucold['col3']/1e6,10**model001ucold['col11'],color='C4',label='0.001 ucold',linestyle='-.')
plt.xlim(1,40)
#plt.ylim(300,900)
plt.legend(ncol=3)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %%
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C5',label='0.010 hot')
plt.plot(model011hot['col3']/1e6,10**model011hot['col11'],color='C0',label='0.011 hot')
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C1',label='0.012 hot')
plt.plot(model013hot['col3']/1e6,10**model013hot['col11'],color='C2',label='0.013 hot')
plt.plot(model014hot['col3']/1e6,10**model014hot['col11'],color='C4',label='0.014 hot')
plt.plot(model010cold['col3']/1e6,10**model010cold['col11'],color='C5',label='0.010 cold',linestyle='--')
plt.plot(model011cold['col3']/1e6,10**model011cold['col11'],color='C0',label='0.011 cold',linestyle='--')
plt.plot(model012cold['col3']/1e6,10**model012cold['col11'],color='C1',label='0.012 cold',linestyle='--')
plt.plot(model013cold['col3']/1e6,10**model013cold['col11'],color='C2',label='0.013 cold',linestyle='--')
plt.plot(model014cold['col3']/1e6,10**model014cold['col11'],color='C4',label='0.014 cold',linestyle='--')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C5',label='0.010 ucold',linestyle='-.')
plt.plot(model011ucold['col3']/1e6,10**model011ucold['col11'],color='C0',label='0.011 ucold',linestyle='-.')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C1',label='0.012 ucold',linestyle='-.')
plt.plot(model013ucold['col3']/1e6,10**model013ucold['col11'],color='C2',label='0.013 ucold',linestyle='-.')
plt.plot(model014ucold['col3']/1e6,10**model014ucold['col11'],color='C4',label='0.014 ucold',linestyle='-.')
plt.xlim(1,40)
#plt.ylim(300,900)
plt.legend(ncol=3)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')

# %%
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C5',label='0.010 hot')
plt.plot(model011hot['col3']/1e6,10**model011hot['col11'],color='C0',label='0.011 hot')
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C1',label='0.012 hot')
plt.plot(model0125hot['col3']/1e6,10**model0125hot['col11'],color='C6',label='0.0125 hot')
plt.plot(model013hot['col3']/1e6,10**model013hot['col11'],color='C2',label='0.013 hot')
plt.plot(model014hot['col3']/1e6,10**model014hot['col11'],color='C4',label='0.014 hot')
#plt.plot(model010cold['col3']/1e6,10**model010cold['col11'],color='C5',label='0.010 cold',linestyle='--')
#plt.plot(model011cold['col3']/1e6,10**model011cold['col11'],color='C0',label='0.011 cold',linestyle='--')
#plt.plot(model012cold['col3']/1e6,10**model012cold['col11'],color='C1',label='0.012 cold',linestyle='--')
#plt.plot(model013cold['col3']/1e6,10**model013cold['col11'],color='C2',label='0.013 cold',linestyle='--')
#plt.plot(model014cold['col3']/1e6,10**model014cold['col11'],color='C4',label='0.014 cold',linestyle='--')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C5',label='0.010 ucold',linestyle='-.')
plt.plot(model011ucold['col3']/1e6,10**model011ucold['col11'],color='C0',label='0.011 ucold',linestyle='-.')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C1',label='0.012 ucold',linestyle='-.')
plt.plot(model0125ucold['col3']/1e6,10**model0125ucold['col11'],color='C6',label='0.0125 ucold',linestyle='-.')
plt.plot(model013ucold['col3']/1e6,10**model013ucold['col11'],color='C2',label='0.013 ucold',linestyle='-.')
plt.plot(model014ucold['col3']/1e6,10**model014ucold['col11'],color='C4',label='0.014 ucold',linestyle='-.')
plt.xlim(1,400)
#plt.ylim(300,900)
plt.legend(ncol=3)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')

# %%
plt.plot(model012warm['col3']/1e6,10**model012warm['col11'],color='C5',label='0.012 warm',linestyle='dotted')
plt.plot(model010warm['col3']/1e6,10**model010warm['col11'],color='C0',label='0.010 warm',linestyle='dotted')
plt.plot(model008warm['col3']/1e6,10**model008warm['col11'],color='C1',label='0.008 warm',linestyle='dotted')
plt.plot(model003warm['col3']/1e6,10**model003warm['col11'],color='C2',label='0.003 warm',linestyle='dotted')
plt.plot(model001warm['col3']/1e6,10**model001warm['col11'],color='C4',label='0.001 warm',linestyle='dotted')
plt.plot(model012cool['col3']/1e6,10**model012cool['col11'],color='C5',label='0.012 cool',linestyle='--')
plt.plot(model010cool['col3']/1e6,10**model010cool['col11'],color='C0',label='0.010 cool',linestyle='--')
plt.plot(model008cool['col3']/1e6,10**model008cool['col11'],color='C1',label='0.008 cool',linestyle='--')
plt.plot(model003cool['col3']/1e6,10**model003cool['col11'],color='C2',label='0.003 cool',linestyle='--')
plt.plot(model001cool['col3']/1e6,10**model001cool['col11'],color='C4',label='0.001 cool',linestyle='--')
plt.plot(model012ucold['col3']/1e6,10**model012ucold['col11'],color='C5',label='0.012 ucold',linestyle='-.')
plt.plot(model010ucold['col3']/1e6,10**model010ucold['col11'],color='C0',label='0.010 ucold',linestyle='-.')
plt.plot(model008ucold['col3']/1e6,10**model008ucold['col11'],color='C1',label='0.008 ucold',linestyle='-.')
plt.plot(model003ucold['col3']/1e6,10**model003ucold['col11'],color='C2',label='0.003 ucold',linestyle='-.')
plt.plot(model001ucold['col3']/1e6,10**model001ucold['col11'],color='C4',label='0.001 ucold',linestyle='-.')
plt.xlim(1,40)
#plt.ylim(300,900)
plt.legend(ncol=3)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %%
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C5',label='0.010 hot')
plt.plot(model011hot['col3']/1e6,10**model011hot['col11'],color='C0',label='0.011 hot')
plt.plot(model012hot['col3']/1e6,10**model012hot['col11'],color='C1',label='0.012 hot')
plt.plot(model013hot['col3']/1e6,10**model013hot['col11'],color='C2',label='0.013 hot')
plt.plot(model014hot['col3']/1e6,10**model014hot['col11'],color='C4',label='0.014 hot')
plt.plot(model012warm['col3']/1e6,10**model012warm['col11'],color='C5',label='0.012 warm',linestyle='dotted')
plt.plot(model010warm['col3']/1e6,10**model010warm['col11'],color='C0',label='0.010 warm',linestyle='dotted')
plt.xlim(0,1)
#plt.ylim(300,900)
plt.legend(ncol=3)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')
