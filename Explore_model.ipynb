# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from astropy.io import ascii

# %%
fname030='/Users/gizis/data/Models/BD_evolution_models/0p03_CD_2021(noZ)_Dusty_ATMO20_stru.txt'
fname025='/Users/gizis/data/Models/BD_evolution_models/0p025_CD_2021(noZ)_Dusty_ATMO20_stru.txt'
fname020='/Users/gizis/data/Models/BD_evolution_models/0p02_CD_2021(noZ)_Dusty_ATMO20_adia_stru.txt'
fname015='/Users/gizis/data/Models/BD_evolution_models/0p015_CD_2021(noZ)_Dusty_ATMO20_stru.txt'
fname012='/Users/gizis/data/Models/BD_evolution_models/0p012_CD_2021(noZ)_Dusty_ATMO20_stru.txt'
#
# hot start models
hname010='/Users/gizis/data/Models/BD_evolution_models/0p01_CD_2021(noZ)_Dusty_ATMO20_hot_start_stru.txt'
hname008='/Users/gizis/data/Models/BD_evolution_models/0p008_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'
hname003='/Users/gizis/data/Models/BD_evolution_models/0p003_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'
hname001='/Users/gizis/data/Models/BD_evolution_models/0p001_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'
# cold start models
cname010='/Users/gizis/data/Models/BD_evolution_models/0p01_CD_2021(noZ)_Dusty_ATMO20_cold_start_stru.txt'
cname008='/Users/gizis/data/Models/BD_evolution_models/0p008_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'
cname003='/Users/gizis/data/Models/BD_evolution_models/0p003_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'
cname001='/Users/gizis/data/Models/BD_evolution_models/0p001_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'

#Note: Should move model files into repository.

# %%
model012=ascii.read(fname012)
model015=ascii.read(fname015)
model020=ascii.read(fname020)
model025=ascii.read(fname025)
model030=ascii.read(fname030)
#
model010hot=ascii.read(hname010)
model008hot=ascii.read(hname008)
model003hot=ascii.read(hname003)
model001hot=ascii.read(hname001)
#
model010cold=ascii.read(cname010)
model008cold=ascii.read(cname008)
model003cold=ascii.read(cname003)
model001cold=ascii.read(cname001)
#

# %%
model025
# Out:
# <Table length=345>
#  col1     col2           col3          col4    col5    col6     col7    col8    col9    col10    ...  col19    col20    col21   col22      col23         col24      col25   col26   col27
# int64   float64        float64       float64   str1  float64  float64 float64 float64  float64   ... float64  float64  float64 float64    float64       float64    float64 float64 float64
# ----- ----------- ----------------- ---------- ---- --------- ------- ------- ------- ---------- ... ------- --------- ------- ------- ------------- ------------- ------- ------- -------
#     0       100.0               0.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941164 ...     0.0 9.492e-16   10.54   14.04           0.0 1.7652272e-06   0.275 0.31509  3.8244
#     1       100.0             100.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941165 ...     0.0 7.051e-05   10.54   14.04 7.2096199e-14 1.7652433e-06   0.275 0.31509  3.8244
#     2       100.0             200.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941166 ...     0.0 7.206e-05   10.54   14.04 7.2533822e-14 1.7652595e-06   0.275 0.31509  3.8244
#     3       100.0             300.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941167 ...     0.0 7.216e-05   10.54   14.04 7.2501382e-14 1.7652757e-06   0.275 0.31509  3.8244
#     4       120.0             420.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941168 ...     0.0 7.224e-05   10.54   14.04 7.2476845e-14 1.7652951e-06   0.275 0.31509  3.8244
#     5       144.0             564.0 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801  -0.494117 ...     0.0 7.234e-05   10.54   14.04 7.2480272e-14 1.7653184e-06   0.275 0.31509  3.8244
#     6       172.8             736.8 -9.085e-15    r 7.079e-42 0.76938 5.77983 0.70801 -0.4941172 ...     0.0 7.245e-05   10.54   14.04 7.2434331e-14 1.7653464e-06   0.275 0.31509  3.8244
#   ...         ...               ...        ...  ...       ...     ...     ...     ...        ... ...     ...       ...     ...     ...           ...           ...     ...     ...     ...
#   337 100000000.0 9529280663.383287 -1.745e-19    r 1.086e-47 2.35142 5.55648 0.70758 -1.0430401 ...     0.0 3.191e-07   20.96   39.79 1.6132184e-09   2.64566e-06 0.27542 0.34649  4.9222
#   338 100000000.0 9629280663.383287 -1.728e-19    r 1.074e-47 2.35184 5.55494 0.70758 -1.0431512 ...     0.0 3.159e-07   20.97   39.82 1.5212693e-09 2.6455681e-06 0.27542 0.34647  4.9224
#   339 100000000.0 9729280663.383287  -1.71e-19    r 1.063e-47 2.35227 5.55339 0.70758  -1.043261 ...     0.0 3.128e-07   20.98   39.85 1.1473511e-09 2.6451941e-06 0.27542 0.34646  4.9226
#   340 100000000.0 9829280663.383287 -1.693e-19    r 1.052e-47 2.35269 5.55182 0.70758 -1.0433695 ...     0.0 3.098e-07    21.0   39.88           0.0 2.6436652e-06 0.27542 0.34644  4.9229
#   341  33333000.0 9862613996.716621 -1.688e-19    r 1.048e-47 2.35283 5.55129 0.70758 -1.0434055 ...     0.0 3.088e-07    21.0   39.89           0.0 2.6372122e-06 0.27542 0.34644  4.9229
#   342  40000000.0 9902613996.716621 -1.681e-19    r 1.044e-47   2.353 5.55064 0.70758 -1.0434485 ...     0.0 3.076e-07    21.0    39.9           0.0  2.638389e-06 0.27542 0.34643   4.923
#   343  48000000.0 9950613996.716621 -1.673e-19    r 1.038e-47 2.35321 5.54983 0.70758 -1.0434999 ...     0.0 3.062e-07   21.01   39.92           0.0 2.6384486e-06 0.27542 0.34643  4.9231
#   344  49386000.0     10000000000.0 -1.665e-19    r 1.033e-47 2.35341 5.54897 0.70758 -1.0435525 ...     0.0 3.047e-07   21.01   39.93           0.0 2.6380035e-06 0.27542 0.34642  4.9232

# %%
plt.plot(10.0**model030['col11'],model030['col12'],label='0.030')
plt.plot(10.0**model025['col11'],model025['col12'],label='0.025')
plt.plot(10.0**model020['col11'],model020['col12'],label='0.020')
plt.plot(10.0**model015['col11'],model015['col12'],label='0.015')
plt.plot(10.0**model012['col11'],model012['col12'],label='0.012')
plt.plot(10.0**model010hot['col11'],model010hot['col12'],label='0.010')
plt.plot(10.0**model008hot['col11'],model008hot['col12'],label='0.008')
plt.xlim(2200,400)
#HR diagram looks conventional although there is a feature at ~1100-1200K
# Out:
# (2200.0, 400.0)

# %%
plt.plot(model030['col3']/1e6,model030['col12'],label='0.030')
plt.plot(model025['col3']/1e6,model025['col12'],label='0.025')
plt.plot(model020['col3']/1e6,model020['col12'],label='0.020')
plt.plot(model015['col3']/1e6,model015['col12'],label='0.015')
plt.plot(model012['col3']/1e6,model012['col12'],label='0.012')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],label='0.010')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],label='0.008')
plt.plot(model003hot['col3']/1e6,model003hot['col12'],label='0.003')
plt.xlim(20,300)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
# Out:
# Text(0, 0.5, 'log Luminosity (solar)')

# %%
plt.plot(model030['col3']/1e6,10**model030['col11'],label='0.030')
plt.plot(model025['col3']/1e6,10**model025['col11'],label='0.025')
plt.plot(model020['col3']/1e6,10**model020['col11'],label='0.020')
plt.plot(model015['col3']/1e6,10**model015['col11'],label='0.015')
plt.plot(model012['col3']/1e6,10**model012['col11'],label='0.012')
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],label='0.010')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],label='0.008')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],label='0.003')
plt.xlim(5,200)
plt.ylim(800,1800)
plt.legend()
plt.xlabel('Age (yr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %% [markdown]
# The dramatic results for Teff as a function of age for young moving groups and clusters. Need to think about it!

# %%
plt.plot(model030['col3'],10**model030['col11'],label='0.030')
plt.plot(model025['col3'],10**model025['col11'],label='0.025')
plt.plot(model020['col3'],10**model020['col11'],label='0.020')
plt.plot(model015['col3'],10**model015['col11'],label='0.015')
plt.plot(model012['col3'],10**model012['col11'],label='0.012')
plt.plot(model010hot['col3'],10**model010hot['col11'],label='0.010')
plt.plot(model008hot['col3'],10**model008hot['col11'],label='0.008')
plt.xlim(1e9,1e10)
plt.ylim(300,900)
plt.legend()
plt.xlabel('Age (yr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')

# %% [markdown]
# At old ages, models are well behaved as we produce late-T and Y dwarfs.

# %%
plt.plot(model030['col3'],model030['col12'],label='0.030')
plt.plot(model025['col3'],model025['col12'],label='0.025')
plt.plot(model020['col3'],model020['col12'],label='0.020')
plt.plot(model015['col3'],model015['col12'],label='0.015')
plt.plot(model012['col3'],model012['col12'],label='0.012')
plt.plot(model010hot['col3'],model010hot['col12'],label='0.010')
plt.plot(model008hot['col3'],model008hot['col12'],label='0.008')
plt.plot(model003hot['col3'],model003hot['col12'],label='0.003')
plt.xlim(1e9,10e9)
plt.legend()
plt.xlabel('Age (yr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-7.5,-4.5)
# Out:
# (-7.5, -4.5)

# %% [markdown]
# At old ages, everything is well behaved.  These are Y dwarfs.

# %%
plt.plot(model030['col3']/1e6,model030['col12'],label='0.030')
plt.plot(model025['col3']/1e6,model025['col12'],label='0.025')
plt.plot(model020['col3']/1e6,model020['col12'],label='0.020')
plt.plot(model015['col3']/1e6,model015['col12'],label='0.015')
plt.plot(model012['col3']/1e6,model012['col12'],label='0.012')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],label='0.010')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],label='0.008')
plt.xlim(10,200)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
# Out:
# (-5.5, -2.0)

# %% [markdown]
# Above we see the relevant ages (beta Pic ~23 Myr; AB Dor/Pleiades ~120 Myr; etc.).   Hot Start only.

# %%
plt.plot(model030['col3']/1e6,model030['col27'],label='0.030')
plt.plot(model025['col3']/1e6,model025['col27'],label='0.025')
plt.plot(model020['col3']/1e6,model020['col27'],label='0.020')
plt.plot(model015['col3']/1e6,model015['col27'],label='0.015')
plt.plot(model012['col3']/1e6,model012['col27'],label='0.012')
plt.plot(model010hot['col3']/1e6,model010hot['col27'],label='0.010')
plt.plot(model008hot['col3']/1e6,model008hot['col27'],label='0.008')
plt.plot(model003hot['col3']/1e6,model003hot['col27'],label='0.003')
plt.xlim(10,100)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('log g (cgs)')
#D-burning big difference!?!?!
# Out:
# Text(0, 0.5, 'log g (cgs)')

# %%
#Let's also consider Bobcat Solar metallicity models
bobcat = ascii.read("/Users/gizis/book/BrownDwarfBook/data/Sonora_Bobcat_nc+0.0_co1.0_mass.my.txt")
#Let us try Saumon & Marley 2009 "Hybrid" models
hybrid = ascii.read("/Users/gizis/book/BrownDwarfBook/data/hybrid_solar_age.txt") 
#

# %%
i_h_m010 = (hybrid["M/Msun"] == 0.010)
i_b_m010 = (bobcat["M/Msun"] == 0.010)
i_h_m020 = (hybrid["M/Msun"] == 0.020)
i_b_m020 = (bobcat["M/Msun"] == 0.020)
i_h_m025 = (hybrid["M/Msun"] == 0.025)
i_b_m025 = (bobcat["M/Msun"] == 0.025)
i_h_m008 = (hybrid["M/Msun"] == 0.008)
i_b_m008 = (bobcat["M/Msun"] == 0.008)
i_h_m012 = (hybrid["M/Msun"] == 0.012)
i_b_m012 = (bobcat["M/Msun"] == 0.012)

# %%
bobcat[i_b_m010]
# Out:
# <Table length=29>
#  M/Msun age(Gyr) log_L/Lsun Teff(K)  log_g   R/Rsun
# float64 float64   float64   float64 float64 float64
# ------- -------- ---------- ------- ------- -------
#    0.01    0.001     -2.729  2368.0    3.62  0.2563
#    0.01    0.002     -2.989  2234.0   3.778  0.2137
#    0.01    0.003     -3.159  2125.0   3.862  0.1941
#    0.01    0.004     -3.291  2035.0   3.918  0.1819
#    0.01    0.006     -3.481  1901.0   3.989  0.1676
#    0.01    0.008     -3.626  1794.0   4.034  0.1591
#    0.01     0.01     -3.746  1706.0   4.066  0.1534
#     ...      ...        ...     ...     ...     ...
#    0.01      1.5     -6.466   425.0   4.371  0.1079
#    0.01      2.0     -6.619   391.0   4.379  0.1069
#    0.01      3.0     -6.792   356.0    4.39  0.1057
#    0.01      4.0     -6.911   334.0   4.397  0.1048
#    0.01      6.0     -7.086   304.0   4.408  0.1035
#    0.01      8.0     -7.221   282.0   4.415  0.1026
#    0.01     10.0      -7.33   266.0   4.421  0.1019
#    0.01     15.0     -7.536   237.0    4.43  0.1008

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='UD')
plt.plot(model010cold['col3']/1e9,10**model010cold['col11'],label='UD')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.010 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='UD')
plt.plot(model010cold['col3']/1e9,10**model010cold['col11'],label='UD (cold)')
plt.xlim(2,10)
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.ylim(200,400)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
print(1.02**4)
plt.title('Comparison: 0.010 $M_\odot$');
# Out:
# 1.08243216

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m010],hybrid['Teff(K)'][i_h_m010],label='Hybrid')
plt.plot(model010hot['col3']/1e9,10**model010hot['col11'],label='UD')
plt.plot(model010cold['col3']/1e9,10**model010cold['col11'],label='UD (cold)')
plt.xlim(0.1,0.5)
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.ylim(500,1000)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m010],bobcat['Teff(K)'][i_b_m010]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
print(1.02**4)
plt.title('Comparison: 0.010 $M_\odot$');
# Out:
# 1.08243216

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m012],hybrid['Teff(K)'][i_h_m012],label='Hybrid')
plt.plot(model012['col3']/1e9,10**model012['col11'],label='UD')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m012],bobcat['Teff(K)'][i_b_m012]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.012 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['Teff(K)'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,10**model008hot['col11'],label='UD')
plt.plot(model008cold['col3']/1e9,10**model008cold['col11'],label='UD (Cold)')
plt.xlim(0.01,0.1)
plt.ylim(700,2000)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['Teff(K)'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,10**model008hot['col11'],label='UD (hot)')
plt.plot(model008cold['col3']/1e9,10**model008cold['col11'],label='UD (cold)')
plt.xlim(1,10)
plt.ylim(200,500)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*1.02,label='Bobcat+2%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['Teff(K)'][i_b_m008]*0.98,label='Bobcat-2%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('Effective Temperature (K)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['log_L/Lsun'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,model008hot['col12'],label='UD')
plt.plot(model008cold['col3']/1e9,model008cold['col12'],label='UD (Cold)')
plt.xlim(0.01,0.1)
plt.ylim(-5,-4)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(1.05),label='Bobcat+5%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(0.95),label='Bobcat-5%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('log Luminosity (solar)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008],label='Bobcat')
plt.plot(hybrid['age(Gyr)'][i_h_m008],hybrid['log_L/Lsun'][i_h_m008],label='Hybrid')
plt.plot(model008hot['col3']/1e9,model008hot['col12'],label='UD')
#plt.plot(model008cold['col3']/1e9,model008cold['col12'],label='UD (Cold)')
plt.xlim(1,10)
plt.ylim(-8,-4)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(1.05),label='Bobcat+5%',color='C0',linestyle='--',alpha=0.5)
plt.plot(bobcat['age(Gyr)'][i_b_m008],bobcat['log_L/Lsun'][i_b_m008]+np.log10(0.95),label='Bobcat-5%',color='C0',linestyle='--',alpha=0.5)
plt.legend()
plt.xlabel('Age (Gyr)')
plt.ylabel('log Luminosity (solar)')
plt.title('Comparison: 0.008 $M_\odot$');

# %%
plt.plot(model010hot['col3']/1e6,10**model010hot['col11'],color='C0',label='0.010 hot')
plt.plot(model008hot['col3']/1e6,10**model008hot['col11'],color='C1',label='0.008 hot')
plt.plot(model003hot['col3']/1e6,10**model003hot['col11'],color='C2',label='0.003 hot')
plt.plot(model001hot['col3']/1e6,10**model001hot['col11'],color='C4',label='0.001 hot')
plt.plot(model010cold['col3']/1e6,10**model010cold['col11'],color='C0',label='0.010 cold',linestyle='--')
plt.plot(model008cold['col3']/1e6,10**model008cold['col11'],color='C1',label='0.008 cold',linestyle='--')
plt.plot(model003cold['col3']/1e6,10**model003cold['col11'],color='C2',label='0.003 cold',linestyle='--')
plt.plot(model001cold['col3']/1e6,10**model001cold['col11'],color='C4',label='0.001 cold',linestyle='--')
plt.xlim(1,40)
#plt.ylim(300,900)
plt.legend()
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
# Out:
# Text(0, 0.5, 'Effective Temperature (K)')
