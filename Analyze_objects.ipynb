# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii

# %%
def mass_powerlaw(size,m0,m1,alpha):
    #dN/dM ~ M**(-alpha)
    factor1= (m1**(1-alpha)-m0**(1-alpha))
    factor2 = m0**(1-alpha)
    return (factor1*np.random.rand(size)+factor2)**(1/(1-alpha))

# %%
dirname='/Users/gizis/data/Models/CELLO'

# %%
#Set up the hot start model names
hname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
# have some extra at finer mass scales:
hname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
#

# %%
#  Read the Hot Start Models
model030hot=ascii.read(hname030)
model025hot=ascii.read(hname025)
model020hot=ascii.read(hname020)
model019hot=ascii.read(hname019)
model018hot=ascii.read(hname018)
model017hot=ascii.read(hname017)
model016hot=ascii.read(hname016)
model015hot=ascii.read(hname015)
model014hot=ascii.read(hname014)
model013hot=ascii.read(hname013)
model012hot=ascii.read(hname012)
model011hot=ascii.read(hname011)
model010hot=ascii.read(hname010)
model009hot=ascii.read(hname009)
model008hot=ascii.read(hname008)
model007hot=ascii.read(hname007)
model006hot=ascii.read(hname006)
model005hot=ascii.read(hname005)
model004hot=ascii.read(hname004)
model003hot=ascii.read(hname003)
model002hot=ascii.read(hname002)
model001hot=ascii.read(hname001)
#
model0155hot=ascii.read(hname0155)
model0145hot=ascii.read(hname0145)
model0135hot=ascii.read(hname0135)
model0125hot=ascii.read(hname0125)

# %%
#Set up the cool start model names
cname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
# have some extra at finer mass scales:
cname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
cname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_coldstart_stru.txt'.format(dirname,'Cool_Start_evolution_models')
#

# %%
#  Read the Cool Start Models
model030cool=ascii.read(cname030)
model025cool=ascii.read(cname025)
model020cool=ascii.read(cname020)
model019cool=ascii.read(cname019)
model018cool=ascii.read(cname018)
model017cool=ascii.read(cname017)
model016cool=ascii.read(cname016)
model015cool=ascii.read(cname015)
model014cool=ascii.read(cname014)
model013cool=ascii.read(cname013)
model012cool=ascii.read(cname012)
model011cool=ascii.read(cname011)
model010cool=ascii.read(cname010)
model009cool=ascii.read(cname009)
model008cool=ascii.read(cname008)
model007cool=ascii.read(cname007)
model006cool=ascii.read(cname006)
model005cool=ascii.read(cname005)
model004cool=ascii.read(cname004)
model003cool=ascii.read(cname003)
model002cool=ascii.read(cname002)
model001cool=ascii.read(cname001)
#
model0155cool=ascii.read(cname0155)
model0145cool=ascii.read(cname0145)
model0135cool=ascii.read(cname0135)
model0125cool=ascii.read(cname0125)

# %%
#Set up the ultracold start model names
uname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
uname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')
# have some extra at finer mass scales:
uname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_ultracoldstart_stru.txt'.format(dirname,'Ultracold_Start_evolution_models')

# %%
model015ucold=ascii.read(uname015)
model014ucold=ascii.read(uname014)
model013ucold=ascii.read(uname013)
model012ucold=ascii.read(uname012)
model011ucold=ascii.read(uname011)
model010ucold=ascii.read(uname010)
model009ucold=ascii.read(uname009)
model008ucold=ascii.read(uname008)
model007ucold=ascii.read(uname007)
model006ucold=ascii.read(uname006)
model005ucold=ascii.read(uname005)
model004ucold=ascii.read(uname004)
model003ucold=ascii.read(uname003)
model002ucold=ascii.read(uname002)
model001ucold=ascii.read(uname001)
model0125ucold=ascii.read(uname0125)

# %%
allhotname='{0}/{1}/hot.all.txt'.format(dirname,'Hot_Start_evolution_models')
allhot=ascii.read(allhotname)
allucoldname='{0}/{1}/ucold.all.txt'.format(dirname,'Ultracold_Start_evolution_models')
allcold=ascii.read(allucoldname)
allcoolname='{0}/{1}/cool.all.txt'.format(dirname,'Cool_Start_evolution_models')
allcool=ascii.read(allcoolname)

# %%
allhot
# Out:
# <Table length=16754>
#  col1     col2           col3           col4    col5    col6     col7     col8    col9  ...   col20    col21   col22      col23         col24      col25   col26   col27
# int64   float64        float64        float64   str1  float64  float64  float64 float64 ...  float64  float64 float64    float64       float64    float64 float64 float64
# ----- ----------- ------------------ ---------- ---- --------- -------- ------- ------- ... --------- ------- ------- ------------- ------------- ------- ------- -------
#     0        10.0                0.0 -2.883e-11    r  1.51e-39 -2.59158 3.96694 0.70801 ...   0.09524    7.28   12.19 3.9297035e-19  6.811811e-08   0.275 0.23909 0.83139
#     1        10.0               10.0 -2.002e-11    r 8.254e-40 -2.39296 4.04389 0.70801 ...   0.07452    7.54   12.47 4.5739779e-20 6.9347913e-08   0.275 0.21941 0.93525
# ...

# %%
from scipy.interpolate import LinearNDInterpolator

# %%
CELLO_interp_logTeff =  LinearNDInterpolator ((allhot['col13'],allhot['col3']/1e6),allhot['col11'],rescale=True)
CELLO_interp_logL =  LinearNDInterpolator ((allhot['col13'],allhot['col3']/1e6),allhot['col12'],rescale=True)
CELLO_cold_interp_logTeff =  LinearNDInterpolator ((allcold['col13'],allcold['col3']/1e6),allcold['col11'],rescale=True)
CELLO_cold_interp_logL =  LinearNDInterpolator ((allcold['col13'],allcold['col3']/1e6),allcold['col12'],rescale=True)
CELLO_cool_interp_logTeff =  LinearNDInterpolator ((allcool['col13'],allcool['col3']/1e6),allcool['col11'],rescale=True)
CELLO_cool_interp_logL =  LinearNDInterpolator ((allcool['col13'],allcool['col3']/1e6),allcool['col12'],rescale=True)

# %%
#now we will analyze some objects

# %%
#First Object: VHS1256b. See Miles et al. 2023
age_vhs1256b = 140 #Myr
age_sigma_vhs1256b = 20
lum_vhs1256b = -4.55
lum_sigma_vhs1256b = 0.009

# %%
plt.plot(model030hot['col3']/1e6,model030hot['col12'],label='0.030')
plt.plot(model025hot['col3']/1e6,model025hot['col12'],label='0.025')
plt.plot(model020hot['col3']/1e6,model020hot['col12'],label='0.020')
plt.plot(model015hot['col3']/1e6,model015hot['col12'],label='0.015')
plt.plot(model014hot['col3']/1e6,model014hot['col12'],label='0.014')
plt.plot(model013hot['col3']/1e6,model013hot['col12'],label='0.013')
plt.plot(model012hot['col3']/1e6,model012hot['col12'],label='0.012')
plt.plot(model011hot['col3']/1e6,model011hot['col11'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'--',label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'--',label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'--',label='0.008')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'--',label='0.005')
plt.errorbar(age_vhs1256b,lum_vhs1256b,yerr=lum_sigma_vhs1256b,xerr=age_sigma_vhs1256b,color='k')
plt.xlim(10,200)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
plt.title('CELLO Hot Start and VHS1256b')
plt.savefig('poster_vhs1256b.png')

# %%
#You can see that the data matches the tracks better than in Miles et al. which uses DS08 hybrid models
#but let's quanitfy it.

# %%
#let's try the method described in Miles et al. to see what models fits
#draw ages
size1=1000000
ages1= np.random.normal(140, 20, size1)
#we follows Miles et al. in using a uniform (flat) mass dirtbutuion.  Perhaps the power low might be better
# but only if companion mass dirtibution is same as isolated/primary objects. That is doubtful. 
masses1=np.random.uniform(0.003,0.029,size1)

# %%
stars1_logL=CELLO_interp_logL(masses1,ages1)

# %%
#now compute chi2 etc. etc.
chi2 = ((stars1_logL - lum_vhs1256b)/lum_sigma_vhs1256b)**2
chi2min=np.min(chi2)
print('Minimum is',chi2min)
prob1=np.exp((chi2min-chi2)/2)
# Out:
# Minimum is 2.1428811131155997e-08

# %%
draw1=np.random.uniform(size=size1)
igood1=(prob1>draw1)

# %%
plt.plot(ages1[igood1],masses1[igood1],'k.',alpha=0.1)

# %%
plt.plot(ages1[igood1],stars1_logL[igood1],'k.',alpha=0.1)

# %%
plt.hist(masses1[igood1])
# Out:
# (array([ 992., 3495., 6281., 4153., 3414., 4367., 4742., 2945.,  952.,
#           31.]),
#  array([0.01072049, 0.01192934, 0.01313819, 0.01434704, 0.0155559 ,
#         0.01676475, 0.0179736 , 0.01918245, 0.0203913 , 0.02160015,
#         0.022809  ]),
#  <BarContainer object of 10 artists>)

# %%
print('Number of good:',np.size(masses1[igood1]))
# Out:
# Number of good: 31372

# %%
ilow=(masses1[igood1]<0.0115)
print('Fraction below 0.0115',np.size(masses1[igood1][ilow])/np.size(masses1[igood1]))
# Out:
# Fraction below 0.0115 0.0012112711972459519

# %%
print('Mean mass',np.mean(masses1[igood1]))
print('Median mass',np.median(masses1[igood1]))
print('STDDEV mass',np.std(masses1[igood1]))
# Out:
# Mean mass 0.015955804689760253
# Median mass 0.015818942823907743
# STDDEV mass 0.0025832728634615026

# %%
from astropy.constants import M_sun,M_jup,R_jup,R_sun

# %%
print('Mean mass (M_Jup)',np.mean(masses1[igood1])*M_sun/M_jup)
print('Median mass',np.median(masses1[igood1])*M_sun/M_jup)
print('STDDEV mass',np.std(masses1[igood1])*M_sun/M_jup)
# Out:
# Mean mass (M_Jup) 16.714750751650758
# Median mass 16.57137898071158
# STDDEV mass 2.706147566720494

# %%
plt.hist(masses1[igood1]*M_sun/M_jup)
# Out:
# (array([ 992., 3495., 6281., 4153., 3414., 4367., 4742., 2945.,  952.,
#           31.]),
#  array([11.23041498, 12.49676604, 13.76311711, 15.02946817, 16.29581924,
#         17.56217031, 18.82852137, 20.09487244, 21.3612235 , 22.62757457,
#         23.89392563]),
#  <BarContainer object of 10 artists>)

# %%
age_vhs1831 = 24 #Myr
age_sigma_vhs1831 = 3
lum_vhs1831 = -4.51
lum_sigma_vhs1831= 0.009

# %%
#draw ages
size2=1000000
ages2= np.random.normal(24, 3, size2)
#we follows Miles et al. in using a uniform (flat) mass dirtbutuion.  
masses2=np.random.uniform(0.002,0.025,size2)
stars2_logL=CELLO_interp_logL(masses2,ages2)

# %%
#now compute chi2 etc. etc.
chi22 = ((stars2_logL - lum_vhs1831)/lum_sigma_vhs1831)**2
chi2min2=np.min(chi22)
print('Minimum is',chi2min2)
prob2=np.exp((chi2min2-chi22)/2)
draw2=np.random.uniform(size=size2)
igood2=(prob2>draw2)
# Out:
# Minimum is 1.0631357980715657e-07

# %%
np.min(ages2)
# Out:
# 9.70660298188606

# %%
print('Mean mass',np.mean(masses2[igood2]))
print('Median mass',np.median(masses2[igood2]))
print('STDDEV mass',np.std(masses2[igood2]))
print('Mean mass (M_Jup)',np.mean(masses2[igood2])*M_sun/M_jup)
print('Median mass',np.median(masses2[igood2])*M_sun/M_jup)
print('STDDEV mass',np.std(masses2[igood2])*M_sun/M_jup)
# Out:
# Mean mass 0.006703176340546712
# Median mass 0.006708913223765784
# STDDEV mass 0.0005579618471053407
# Mean mass (M_Jup) 7.022016373044751
# Median mass 7.028026134066685
# STDDEV mass 0.5845015895238167

# %%
age_51erib = 24 #Myr
age_sigma_51erib = 3
lum_51erib = -5.5
lum_sigma_51erib = 0.2

# %%
#draw ages
size3=1000000
ages3= np.random.normal(24, 3, size3)
#we follows Miles et al. in using a uniform (flat) mass dirtbutuion.  
masses3=np.random.uniform(0.0011,0.015,size3)
stars3_logL=CELLO_interp_logL(masses3,ages3)
cold3_logL=CELLO_cold_interp_logL(masses3,ages3)

# %%
#now compute chi2 etc. etc.
chi23 = ((stars3_logL - lum_51erib)/lum_sigma_51erib)**2
chi2min3=np.min(chi23)
print('Minimum is',chi2min3)
prob3=np.exp((chi2min3-chi23)/2)
draw3=np.random.uniform(size=size3)
igood3=(prob3>draw3)
#
cold_chi23 = ((cold3_logL - lum_51erib)/lum_sigma_51erib)**2
cold_chi2min3=np.min(cold_chi23)
print('Cold Minimum is',cold_chi2min3)
cold_prob3=np.exp((cold_chi2min3-cold_chi23)/2)
cold_draw3=np.random.uniform(size=size3)
icgood3=(cold_prob3>cold_draw3)
# Out:
# Minimum is 1.0403383878347663e-12
# Cold Minimum is 3.6489249072463435e-12

# %%
print("51 Eri b")
print('HOT')
print('Mean mass',np.mean(masses3[igood3]))
print('Median mass',np.median(masses3[igood3]))
print('STDDEV mass',np.std(masses3[igood3]))
print('Mean mass (M_Jup)',np.mean(masses3[igood3])*M_sun/M_jup)
print('Median mass',np.median(masses3[igood3])*M_sun/M_jup)
print('STDDEV mass',np.std(masses3[igood3])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses3[icgood3]))
print('Median mass',np.median(masses3[icgood3]))
print('STDDEV mass',np.std(masses3[icgood3]))
print('Mean mass (M_Jup)',np.mean(masses3[icgood3])*M_sun/M_jup)
print('Median mass',np.median(masses3[icgood3])*M_sun/M_jup)
print('STDDEV mass',np.std(masses3[icgood3])*M_sun/M_jup)
# Out:
# 51 Eri b
# HOT
# Mean mass 0.0029564190874298815
# Median mass 0.002920516614760413
# STDDEV mass 0.0005633116311802838
# Mean mass (M_Jup) 3.0970426828755424
# Median mass 3.059432490615967
# STDDEV mass 0.5901058388316068
# COLD
# Mean mass 0.008093378242413086
# Median mass 0.008142304143397052
# STDDEV mass 0.0023599855708547296
# Mean mass (M_Jup) 8.478343943855375
# Median mass 8.52959703049987
# STDDEV mass 2.4722394991237353

# %%
plt.plot(ages3[igood3],masses3[igood3],'k.')

# %%
age_aflepb = 24 #Myr
age_sigma_aflepb = 3
lum_aflepb = -5.23
lum_sigma_aflepb = 0.06

# %%
#draw ages
size4=1000000
ages4= np.random.normal(24, 3, size4)
#we follows Miles et al. in using a uniform (flat) mass dirtbutuion.  
masses4=np.random.uniform(0.0011,0.015,size4)
stars4_logL=CELLO_interp_logL(masses4,ages4)
cold4_logL=CELLO_cold_interp_logL(masses4,ages4)

# %%
#now compute chi2 etc. etc.
chi24 = ((stars4_logL - lum_aflepb)/lum_sigma_aflepb)**2
chi2min4=np.min(chi24)
print('Minimum is',chi2min4)
prob4=np.exp((chi2min4-chi24)/2)
draw4=np.random.uniform(size=size4)
igood4=(prob4>draw4)
#
cold_chi24 = ((cold4_logL - lum_aflepb)/lum_sigma_aflepb)**2
cold_chi2min4=np.min(cold_chi24)
print('Cold Minimum is',cold_chi2min4)
cold_prob4=np.exp((cold_chi2min4-cold_chi24)/2)
cold_draw4=np.random.uniform(size=size4)
icgood4=(cold_prob4>cold_draw4)
# Out:
# Minimum is 6.816496113230661e-10
# Cold Minimum is 3.497882957261297e-08

# %%
print("AF Lep b")
print('HOT')
print('Mean mass',np.mean(masses4[igood4]))
print('Median mass',np.median(masses4[igood4]))
print('STDDEV mass',np.std(masses4[igood4]))
print('Mean mass (M_Jup)',np.mean(masses4[igood4])*M_sun/M_jup)
print('Median mass',np.median(masses4[igood4])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4[igood4])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses4[icgood4]))
print('Median mass',np.median(masses4[icgood4]))
print('STDDEV mass',np.std(masses4[icgood4]))
print('Mean mass (M_Jup)',np.mean(masses4[icgood4])*M_sun/M_jup)
print('Median mass',np.median(masses4[icgood4])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4[icgood4])*M_sun/M_jup)
# Out:
# AF Lep b
# HOT
# Mean mass 0.0036348546356469026
# Median mass 0.0036354958714634998
# STDDEV mass 0.0003112034917804213
# Mean mass (M_Jup) 3.807748367107469
# Median mass 3.8084201036357017
# STDDEV mass 0.3260060460310947
# COLD
# Mean mass 0.012129128354057946
# Median mass 0.01212908888049541
# STDDEV mass 1.8208347619317452e-05
# Mean mass (M_Jup) 12.7060565866017
# Median mass 12.706015235458846
# STDDEV mass 0.019074437044947164

# %%
teff4hot=CELLO_interp_logTeff(np.mean(masses4[igood4]),age_aflepb)
teff4cold=CELLO_cold_interp_logTeff(np.mean(masses4[icgood4]),age_aflepb)
print("Teff (hot): ",10**teff4hot)
print("Teff (cold): ",10**teff4cold)
print(2.8*M_jup/M_sun)
# Out:
# Teff (hot):  783.3625010020047
# Teff (cold):  831.4818975334322
# 0.00267286385511411

# %%
#this is the measured mass. note different values exist in the literature 
mass_aflepb = 2.8*M_jup/M_sun
mass_sigma_aflepb = 0.6*M_jup/M_sun

# %%
teff4hot=CELLO_interp_logTeff(2.8*M_jup/M_sun,age_aflepb)
teff4cold=CELLO_cold_interp_logTeff(2.8*M_jup/M_sun,age_aflepb)
print("Teff (hot): ",10**teff4hot)
print("Teff (cold): ",10**teff4cold)
# Out:
# Teff (hot):  645.5856585223632
# Teff (cold):  516.4767574038046

# %%
#Let us instead follow Zhang 2024 and consider the mass constraint! 
# Model 4z will use the known age, known mass, and known luminosity!
#draw ages
size4z=1000000
ages4z= np.random.normal(24, 3, size4z)
#we use the prior of the observed mass  
masses4z=np.random.normal(mass_aflepb,mass_sigma_aflepb,size4)
#however, we cannot have masses less than 0.001 solar mass (much less negative)
# so we need to cut them off
itoolow = (masses4z < 0.00101)
masses4z[itoolow] = 0.00101
stars4z_logL=CELLO_interp_logL(masses4z,ages4z)
cold4z_logL=CELLO_cold_interp_logL(masses4z,ages4z)
#now compute chi2 etc. etc.
chi24z = ((stars4z_logL - lum_aflepb)/lum_sigma_aflepb)**2
chi2min4z=np.min(chi24z)
print('Minimum is',chi2min4z)
prob4z=np.exp((chi2min4z-chi24z)/2)
draw4z=np.random.uniform(size=size4z)
igood4z=(prob4z>draw4z)
#
cold_chi24z = ((cold4z_logL - lum_aflepb)/lum_sigma_aflepb)**2
cold_chi2min4z=np.min(cold_chi24z)
print('Cold Minimum is',cold_chi2min4z)
cold_prob4z=np.exp((cold_chi2min4z-cold_chi24z)/2)
cold_draw4z=np.random.uniform(size=size4z)
icgood4z=(cold_prob4z>cold_draw4z)
#
# Out:
# Minimum is 8.744452153152769e-09
# Cold Minimum is 44.58444387998155

# %%
print("AF Lep b Mass and Age and Lum")
print('HOT')
print('Mean mass',np.mean(masses4z[igood4z]))
print('Median mass',np.median(masses4z[igood4z]))
print('STDDEV mass',np.std(masses4z[igood4z]))
print('Mean mass (M_Jup)',np.mean(masses4z[igood4z])*M_sun/M_jup)
print('Median mass',np.median(masses4z[igood4z])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4z[igood4z])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses4z[icgood4z]))
print('Median mass',np.median(masses4z[icgood4z]))
print('STDDEV mass',np.std(masses4z[icgood4z]))
print('Mean mass (M_Jup)',np.mean(masses4z[icgood4z])*M_sun/M_jup)
print('Median mass',np.median(masses4z[icgood4z])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4z[icgood4z])*M_sun/M_jup)
# Out:
# AF Lep b Mass and Age and Lum
# HOT
# Mean mass 0.003412051789290449
# Median mass 0.0034082058375660565
# STDDEV mass 0.0002696948168379429
# Mean mass (M_Jup) 3.574347788696252
# Median mass 3.570318902298729
# STDDEV mass 0.2825229896021028
# COLD
# Mean mass 0.005187299083082784
# Median mass 0.005059495890054255
# STDDEV mass 0.0006331731738006641
# Mean mass (M_Jup) 5.434035633667438
# Median mass 5.300153415987255
# STDDEV mass 0.6632903816817005

# %%
#Let us instead follow Zhang 2024 and consider the mass constraint! 
# Model 4y -- probably more faithful to Zhang --  will use the known mass, and known luminosity
# but not the age!
#draw ages
size4y=1000000
ages4y= np.random.uniform(1, 200, size4y)
#we use the prior of the observed mass  
masses4y=np.random.normal(mass_aflepb,mass_sigma_aflepb,size4y)
#however, we cannot have masses less than 0.001 solar mass (much less negative)
# so we need to cut them off
itoolow = (masses4y < 0.00101)
masses4y[itoolow] = 0.00101
stars4y_logL=CELLO_interp_logL(masses4y,ages4y)
cold4y_logL=CELLO_cold_interp_logL(masses4y,ages4y)
#now compute chi2 etc. etc.
chi24y = ((stars4y_logL - lum_aflepb)/lum_sigma_aflepb)**2
chi2min4y=np.min(chi24y)
print('Minimum is',chi2min4y)
prob4y=np.exp((chi2min4y-chi24y)/2)
draw4y=np.random.uniform(size=size4y)
igood4y=(prob4y>draw4y)
#
cold_chi24y = ((cold4y_logL - lum_aflepb)/lum_sigma_aflepb)**2
cold_chi2min4y=np.min(cold_chi24y)
print('Cold Minimum is',cold_chi2min4y)
cold_prob4y=np.exp((cold_chi2min4y-cold_chi24y)/2)
cold_draw4y=np.random.uniform(size=size4y)
icgood4y=(cold_prob4y>cold_draw4y)
#
# Out:
# Minimum is 1.9940751958175026e-09
# Cold Minimum is 19.40269366854062

# %%
print("AF Lep b Mass and Lum but free age")
print("measured mass (solar) is ",mass_aflepb)
print("measured mass (jupiter) is ",mass_aflepb*M_sun/M_jup)
print('HOT')
print('Mean mass',np.mean(masses4y[igood4y]))
print('Median mass',np.median(masses4y[igood4y]))
print('STDDEV mass',np.std(masses4y[igood4y]))
print('Mean mass (M_Jup)',np.mean(masses4y[igood4y])*M_sun/M_jup)
print('Median mass',np.median(masses4y[igood4y])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4y[igood4y])*M_sun/M_jup)
print('Mean age',np.mean(ages4y[igood4y]))
print('Median age',np.median(ages4y[igood4y]))
print('STDDEV age',np.std(ages4y[igood4y]))
#
print('COLD')
print('Mean mass',np.mean(masses4y[icgood4y]))
print('Median mass',np.median(masses4y[icgood4y]))
print('STDDEV mass',np.std(masses4y[icgood4y]))
print('Mean mass (M_Jup)',np.mean(masses4y[icgood4y])*M_sun/M_jup)
print('Median mass',np.median(masses4y[icgood4y])*M_sun/M_jup)
print('STDDEV mass',np.std(masses4y[icgood4y])*M_sun/M_jup)
print('Mean age',np.mean(ages4y[icgood4y]))
print('Median age',np.median(ages4y[icgood4y]))
print('STDDEV age',np.std(ages4y[icgood4y]))
#
# Out:
# AF Lep b Mass and Lum but free age
# measured mass (solar) is  0.00267286385511411
# measured mass (jupiter) is  2.8
# HOT
# Mean mass 0.0028720450107762112
# Median mass 0.002881635616621146
# STDDEV mass 0.0005500622956380036
# Mean mass (M_Jup) 3.008655309841838
# Median mass 3.0187020977896926
# STDDEV mass 0.5762262918253489
# Mean age 16.350354357757105
# Median age 15.82180403648566
# STDDEV age 5.897844195829719
# COLD
# Mean mass 0.004075539898239999
# Median mass 0.004047664437294946
# STDDEV mass 0.0002284523446333924
# Mean mass (M_Jup) 4.269395051019094
# Median mass 4.240193679427792
# STDDEV mass 0.23931879798127242
# Mean age 1.7221501375214536
# Median age 1.5166353955172096
# STDDEV age 0.7154082449656277

# %%
plt.plot(cold4y_logL[icgood4y],masses4y[icgood4y],'.',alpha=0.01)
plt.plot(stars4y_logL[igood4y],masses4y[igood4y],'.',alpha=0.01)

# %%
plt.plot(ages4y[icgood4y],masses4y[icgood4y],'.',alpha=0.01)
plt.plot(ages4y[igood4y],masses4y[igood4y],'.',alpha=0.01)

# %%
plt.plot(ages4z[icgood4z],masses4z[icgood4z],'.',alpha=0.01)
plt.plot(ages4z[igood4z],masses4z[igood4z],'.',alpha=0.01)

# %%
age_wisea1147 = 10 #Myr
age_sigma_wisea1147 = 3
lum_wisea1147 = -4.42
lum_sigma_wisea1147 = 0.11

# %%
print("WISEA 1147-2040")
#draw ages
size5=1000000
ages5= np.random.normal(age_wisea1147, age_sigma_wisea1147, size5)
#
# need to cut off ages that are too low
itoolow=(ages5 < 2)
ages5[itoolow]=2.0
# flat mass prior 
masses5=np.random.uniform(0.0011,0.015,size5)
stars5_logL=CELLO_interp_logL(masses5,ages5)
cold5_logL=CELLO_cold_interp_logL(masses5,ages5)
#now compute chi2 etc. etc.
chi25 = ((stars5_logL - lum_wisea1147)/lum_sigma_wisea1147)**2
chi2min5=np.min(chi25)
print('Minimum is',chi2min5)
prob5=np.exp((chi2min5-chi25)/2)
draw5=np.random.uniform(size=size5)
igood5=(prob5>draw5)
#
cold_chi25 = ((cold5_logL - lum_wisea1147)/lum_sigma_wisea1147)**2
cold_chi2min5=np.min(cold_chi25)
print('Cold Minimum is',cold_chi2min5)
cold_prob5=np.exp((cold_chi2min5-cold_chi25)/2)
cold_draw5=np.random.uniform(size=size5)
icgood5=(cold_prob5>cold_draw5)
# Out:
# WISEA 1147-2040
# Minimum is 1.3268796891100345e-10
# Cold Minimum is 5.005771361213585e-08

# %%
print("WISEA 1147-2040")
print('HOT')
print('Mean mass',np.mean(masses5[igood5]))
print('Median mass',np.median(masses5[igood5]))
print('STDDEV mass',np.std(masses5[igood5]))
print('Mean mass (M_Jup)',np.mean(masses5[igood5])*M_sun/M_jup)
print('Median mass',np.median(masses5[igood5])*M_sun/M_jup)
print('STDDEV mass',np.std(masses5[igood5])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses5[icgood5]))
print('Median mass',np.median(masses5[icgood5]))
print('STDDEV mass',np.std(masses5[icgood5]))
print('Mean mass (M_Jup)',np.mean(masses5[icgood5])*M_sun/M_jup)
print('Median mass',np.median(masses5[icgood5])*M_sun/M_jup)
print('STDDEV mass',np.std(masses5[icgood5])*M_sun/M_jup)
#
print('Median age (hot):',np.median(ages5[igood5]))
print('Median age (cold):',np.median(ages5[icgood5]))
# Out:
# WISEA 1147-2040
# HOT
# Mean mass 0.005206789757627065
# Median mass 0.005124929146903904
# STDDEV mass 0.0011409240085709057
# Mean mass (M_Jup) 5.4544533921774985
# Median mass 5.368699039374869
# STDDEV mass 1.1951926462270757
# COLD
# Mean mass 0.012370285394642659
# Median mass 0.012369884140997708
# STDDEV mass 3.325962342319576e-05
# Mean mass (M_Jup) 12.958684385935822
# Median mass 12.958264046454739
# STDDEV mass 0.03484163452873373
# Median age (hot): 10.585777727167365
# Median age (cold): 10.071143603165169

# %%
teff5hot=CELLO_interp_logTeff(np.median(masses5[igood5])*M_jup/M_sun,age_wisea1147)
teff5cold=CELLO_cold_interp_logTeff(np.median(masses5[icgood5])*M_jup/M_sun,age_wisea1147)
print("Teff (hot): ",10**teff4hot)
print("Teff (cold): ",10**teff4cold)
# Out:
# Teff (hot):  645.5856585223632
# Teff (cold):  516.4767574038046

# %%
#Conclusion:  This is just as in the discovery paper, nothing new here. The luminosity and age gives
# a low mass.  Teff would give a much higher one. One wonders how accurate the luminosity is.

# %%
#AB Dor member Bowler et al. 2017AJ....153...18B   2M2236+4751b
age_2m2236b = 120 #Myr
age_sigma_2m2236b = 10
lum_2m2236b = -4.5
lum_sigma_2m2236b = 0.05

# %%
#draw ages
size8=1000000
ages8= np.random.normal(age_2m2236b, age_sigma_2m2236b, size8)
#we follows Miles et al. in using a uniform (flat) mass dirtbutuion.  
masses8=np.random.uniform(0.002,0.025,size8)
stars8_logL=CELLO_interp_logL(masses8,ages8)
print("2M2236+4751b")
cool8_logL=CELLO_cool_interp_logL(masses8,ages8)
#now compute chi2 etc. etc.
chi28 = ((stars8_logL - lum_2m2236b)/lum_sigma_2m2236b)**2
chi2min8=np.min(chi28)
print('Minimum is',chi2min8)
prob8=np.exp((chi2min8-chi28)/2)
draw8=np.random.uniform(size=size8)
igood8=(prob8>draw8)
#
cool_chi28 = ((cool8_logL - lum_2m2236b)/lum_sigma_2m2236b)**2
cool_chi2min8=np.min(cool_chi28)
print('Cool Minimum is',cool_chi2min8)
cool_prob8=np.exp((cool_chi2min8-cool_chi28)/2)
cool_draw8=np.random.uniform(size=size8)
icgood8=(cool_prob8>cool_draw8)
#
# Out:
# 2M2236+4751b
# Minimum is 1.4322288757072768e-10
# Cool Minimum is 9.784135580715232e-14

# %%
print("2M2236+4751b")
print('HOT')
print('Mean mass',np.mean(masses8[igood8]))
print('Median mass',np.median(masses8[igood8]))
print('STDDEV mass',np.std(masses8[igood8]))
print('Mean mass (M_Jup)',np.mean(masses8[igood8])*M_sun/M_jup)
print('Median mass',np.median(masses8[igood8])*M_sun/M_jup)
print('STDDEV mass',np.std(masses8[igood8])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses8[igood8])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses8[icgood8]))
print('Median mass',np.median(masses8[icgood8]))
print('STDDEV mass',np.std(masses8[icgood8]))
print('Mean mass (M_Jup)',np.mean(masses8[icgood8])*M_sun/M_jup)
print('Median mass',np.median(masses8[icgood8])*M_sun/M_jup)
print('STDDEV mass',np.std(masses8[icgood8])*M_sun/M_jup)
#
# Out:
# 2M2236+4751b
# HOT
# Mean mass 0.015707449543480863
# Median mass 0.015881447588378148
# STDDEV mass 0.0021033115506785003
# Mean mass (M_Jup) 16.45458246502001
# Median mass 16.63685681647275
# STDDEV mass 2.2033566470778494
# MINIMUM mass 11.56867625367542
# COLD
# Mean mass 0.015822320345385738
# Median mass 0.01605572700674702
# STDDEV mass 0.002217241262159421
# Mean mass (M_Jup) 16.57491715573695
# Median mass 16.819425925071066
# STDDEV mass 2.3227054839204797

# %%
#So this also diffewrs from the Bowler et al. discovery paper

# %%
#HR 8799 planets
#
# IAU rec
teffsun = 5772
#
#See new JWST data 2024A&A...686A..33B
#they don't report lumoinosities but they do have teff, radius fits which is the same thing.
# A is the "Atlas results" and B is the "exo-Mol" results
hrAteffb = 1100.0
hrAradb = 0.86 * R_jup / R_sun
hrBteffb= 950.0
hrBradb = 1.07 * R_jup / R_sun
#
hrAlumb = ((hrAteffb/teffsun)**4) * (hrAradb**2)
hrAloglumb = np.log10(hrAlumb)
hrBlumb = ((hrBteffb/teffsun)**4) * (hrBradb**2)
hrBloglumb = np.log10(hrBlumb)
#
hrAteffc = 1300.0
hrAradc = 0.90 * R_jup / R_sun
hrBteffc= 1150.0
hrBradc = 1.12 * R_jup / R_sun
#
hrAlumc = ((hrAteffc/teffsun)**4) * (hrAradc**2)
hrAloglumc = np.log10(hrAlumc)
hrBlumc = ((hrBteffc/teffsun)**4) * (hrBradc**2)
hrBloglumc = np.log10(hrBlumc)
#
hrAteffd = 1200.0
hrAradd = 1.10 * R_jup / R_sun
hrBteffd= 1150.0
hrBradd = 1.12 * R_jup / R_sun
#
hrAlumd = ((hrAteffd/teffsun)**4) * (hrAradd**2)
hrAloglumd = np.log10(hrAlumd)
hrBlumd = ((hrBteffd/teffsun)**4) * (hrBradd**2)
hrBloglumd = np.log10(hrBlumd)
#
hrAteffe = 1200.0
hrArade = 1.05 * R_jup / R_sun
hrBteffe= 1300.0
hrBrade = 1.06 * R_jup / R_sun
#
hrAlume = ((hrAteffe/teffsun)**4) * (hrArade**2)
hrAloglume = np.log10(hrAlume)
hrBlume = ((hrBteffe/teffsun)**4) * (hrBrade**2)
hrBloglume = np.log10(hrBlume)
#
age_HR8799=30
#
# let us not try to be realistic in terms of the errors but simply indicative

# %%
print('HR8799b',hrAloglumb,hrBloglumb)
print('HR8799c',hrAloglumc,hrBloglumc)
print('HR8799d',hrAloglumd,hrBloglumd)
print('HR8799e',hrAloglume,hrBloglume)
print('Compare -5.1 and -4.7, -4.7, -4.7 in Sepulveda and Bowler')
# Out:
# HR8799b -4.987066759895413 -5.0519724264896375
# HR8799c -4.657375974909451 -4.680406996260638
# HR8799d -4.622124048508499 -4.680406996260638
# HR8799e -4.662530820685072 -4.515249263258561
# Compare -5.1 and -4.7, -4.7, -4.7 in Sepulveda and Bowler

# %%
#draw ages
size9=1000000
ages9= np.random.normal(30,1, size9)
# the real uncertainty in age is of course much more than 1 Myr!!!!
#we f 
masses9=np.random.uniform(0.002,0.014,size9)
stars9_logL=CELLO_interp_logL(masses9,ages9)
cool9_logL=CELLO_cool_interp_logL(masses9,ages9)
cold9_logL=CELLO_cold_interp_logL(masses9,ages9)
#now compute chi2 etc. etc.
chi29b = ((stars9_logL - hrAloglumb)/0.05)**2
chi2min9b=np.min(chi29b)
print('Minimum is',chi2min9b)
prob9b=np.exp((chi2min9b-chi29b)/2)
draw9b=np.random.uniform(size=size9)
igood9b=(prob9b>draw9b)
#
cool_chi29b = ((cool9_logL - hrAloglumb)/0.05)**2
cool_chi2min9b=np.min(cool_chi29b)
print('Cool Minimum is',cool_chi2min9b)
cool_prob9b=np.exp((cool_chi2min9b-cool_chi29b)/2)
cool_draw9b=np.random.uniform(size=size9)
icgood9b=(cool_prob9b>cool_draw9b)
#
#
cold_chi29b = ((cold9_logL - hrAloglumb)/0.05)**2
cold_chi2min9b=np.min(cold_chi29b)
print('Cold Minimum is',cold_chi2min9b)
cold_prob9b=np.exp((cold_chi2min9b-cold_chi29b)/2)
cold_draw9b=np.random.uniform(size=size9)
icoldgood9b=(cold_prob9b>cold_draw9b)
#
#
teff9bhot=CELLO_interp_logTeff(np.median(masses9[igood9b]),ages9[igood9b])
teff9bcool=CELLO_cool_interp_logTeff(np.median(masses9[icgood9b]),ages9[igood9b])
print("Teff (hot): ",10**np.median(teff9bhot))
print("Teff (cool): ",10**np.median(teff9bcool))
#
print("HR8799b")
print('HOT')
print('Mean mass',np.mean(masses9[igood9b]))
print('Median mass',np.median(masses9[igood9b]))
print('STDDEV mass',np.std(masses9[igood9b]))
print('Mean mass (M_Jup)',np.mean(masses9[igood9b])*M_sun/M_jup)
print('Median mass',np.median(masses9[igood9b])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[igood9b])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses9[igood9b])*M_sun/M_jup)
#
print('COOL')
print('Mean mass',np.mean(masses9[icgood9b]))
print('Median mass',np.median(masses9[icgood9b]))
print('STDDEV mass',np.std(masses9[icgood9b]))
print('Mean mass (M_Jup)',np.mean(masses9[icgood9b])*M_sun/M_jup)
print('Median mass',np.median(masses9[icgood9b])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icgood9b])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses9[icoldgood9b]))
print('Median mass',np.median(masses9[icoldgood9b]))
print('STDDEV mass',np.std(masses9[icoldgood9b]))
print('Mean mass (M_Jup)',np.mean(masses9[icoldgood9b])*M_sun/M_jup)
print('Median mass',np.median(masses9[icoldgood9b])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icoldgood9b])*M_sun/M_jup)
#
# Out:
# Minimum is 4.5092716228141456e-10
# Cool Minimum is 4.006135886598062e-08
# Cold Minimum is 1.6757678758926787e-08
# Teff (hot):  900.2136304549261
# Teff (cool):  903.5271574789659
# HR8799b
# HOT
# Mean mass 0.004921459018662444
# Median mass 0.004921041965427638
# STDDEV mass 0.00018917901059942193
# Mean mass (M_Jup) 5.155550749765571
# Median mass 5.155113859179011
# STDDEV mass 0.19817740760154332
# MINIMUM mass 4.420630401227737
# COOL
# Mean mass 0.00516776681288713
# Median mass 0.0051659811196956016
# STDDEV mass 0.0002090621696300337
# Mean mass (M_Jup) 5.413574300987441
# Median mass 5.411703670380232
# STDDEV mass 0.21900631932452225
# COLD
# Mean mass 0.012207690544933807
# Median mass 0.012207949131211725
# STDDEV mass 1.5727545179003972e-05
# Mean mass (M_Jup) 12.788355628519426
# Median mass 12.788626514586737
# STDDEV mass 0.016475633959789203

# %%
#now compute chi2 etc. etc.
chi29c = ((stars9_logL - hrAloglumc)/0.05)**2
chi2min9c=np.min(chi29c)
print('Minimum is',chi2min9c)
prob9c=np.exp((chi2min9c-chi29c)/2)
draw9c=np.random.uniform(size=size9)
igood9c=(prob9c>draw9c)
#
cool_chi29c = ((cool9_logL - hrAloglumc)/0.05)**2
cool_chi2min9c=np.min(cool_chi29c)
print('Cool Minimum is',cool_chi2min9c)
cool_prob9c=np.exp((cool_chi2min9c-cool_chi29c)/2)
cool_draw9c=np.random.uniform(size=size9)
icgood9c=(cool_prob9c>cool_draw9c)
#
#
cold_chi29c = ((cold9_logL - hrAloglumc)/0.05)**2
cold_chi2min9c=np.min(cold_chi29c)
print('Cold Minimum is',cold_chi2min9c)
cold_prob9c=np.exp((cold_chi2min9c-cold_chi29c)/2)
cold_draw9c=np.random.uniform(size=size9)
icoldgood9c=(cold_prob9c>cold_draw9c)
#
teff9chot=CELLO_interp_logTeff(np.median(masses9[igood9c]),ages9[igood9c])
teff9ccool=CELLO_cool_interp_logTeff(np.median(masses9[icgood9c]),ages9[icgood9c])
print("Teff (hot): ",10**np.median(teff9chot))
print("Teff (cool): ",10**np.median(teff9ccool))
#
print("HR8799c")
print('HOT')
print('Mean mass',np.mean(masses9[igood9c]))
print('Median mass',np.median(masses9[igood9c]))
print('STDDEV mass',np.std(masses9[igood9c]))
print('Mean mass (M_Jup)',np.mean(masses9[igood9c])*M_sun/M_jup)
print('Median mass',np.median(masses9[igood9c])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[igood9c])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses9[igood9c])*M_sun/M_jup)
#
print('COOL')
print('Mean mass',np.mean(masses9[icgood9c]))
print('Median mass',np.median(masses9[icgood9c]))
print('STDDEV mass',np.std(masses9[icgood9c]))
print('Mean mass (M_Jup)',np.mean(masses9[icgood9c])*M_sun/M_jup)
print('Median mass',np.median(masses9[icgood9c])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icgood9c])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses9[icoldgood9c]))
print('Median mass',np.median(masses9[icoldgood9c]))
print('STDDEV mass',np.std(masses9[icoldgood9c]))
print('Mean mass (M_Jup)',np.mean(masses9[icoldgood9c])*M_sun/M_jup)
print('Median mass',np.median(masses9[icoldgood9c])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icoldgood9c])*M_sun/M_jup)
#
# Out:
# Minimum is 1.2768414892594909e-11
# Cool Minimum is 3.2484813363494523e-13
# Cold Minimum is 3.846127060730464e-09
# Teff (hot):  1089.6029335798157
# Teff (cool):  1090.532128185561
# HR8799c
# HOT
# Mean mass 0.006276530105068186
# Median mass 0.006218935116196476
# STDDEV mass 0.0003995073437908657
# Mean mass (M_Jup) 6.575076489797734
# Median mass 6.514741965638477
# STDDEV mass 0.4185101162089185
# MINIMUM mass 5.506973881306496
# COOL
# Mean mass 0.006782379100824849
# Median mass 0.00669259333755894
# STDDEV mass 0.000499676319548273
# Mean mass (M_Jup) 7.104986453378048
# Median mass 7.010929984073213
# STDDEV mass 0.5234436808512398
# COLD
# Mean mass 0.012310356928409821
# Median mass 0.012310445251705441
# STDDEV mass 1.548808579567328e-05
# Mean mass (M_Jup) 12.895905391363806
# Median mass 12.89599791580244
# STDDEV mass 0.01622478456765011

# %%
#now compute chi2 etc. etc.
chi29d = ((stars9_logL - hrAloglumd)/0.05)**2
chi2min9d=np.min(chi29d)
print('Minimum is',chi2min9d)
prob9d=np.exp((chi2min9d-chi29d)/2)
draw9d=np.random.uniform(size=size9)
igood9d=(prob9d>draw9d)
#
cool_chi29d = ((cool9_logL - hrAloglumd)/0.05)**2
cool_chi2min9d=np.min(cool_chi29d)
print('Cool Minimum is',cool_chi2min9d)
cool_prob9d=np.exp((cool_chi2min9d-cool_chi29d)/2)
cool_draw9d=np.random.uniform(size=size9)
icgood9d=(cool_prob9d>cool_draw9d)
#
#
cold_chi29d = ((cold9_logL - hrAloglumd)/0.05)**2
cold_chi2min9d=np.min(cold_chi29d)
print('Cold Minimum is',cold_chi2min9d)
cold_prob9d=np.exp((cold_chi2min9d-cold_chi29d)/2)
cold_draw9d=np.random.uniform(size=size9)
icoldgood9d=(cold_prob9d>cold_draw9d)
#
teff9dhot=CELLO_interp_logTeff(np.median(masses9[igood9d]),ages9[igood9d])
teff9dcool=CELLO_cool_interp_logTeff(np.median(masses9[icgood9d]),ages9[igood9d])
print("Teff (hot): ",10**np.median(teff9dhot))
print("Teff (cool): ",10**np.median(teff9dcool))
#
print("HR8799d")
print('HOT')
print('Mean mass',np.mean(masses9[igood9d]))
print('Median mass',np.median(masses9[igood9d]))
print('STDDEV mass',np.std(masses9[igood9d]))
print('Mean mass (M_Jup)',np.mean(masses9[igood9d])*M_sun/M_jup)
print('Median mass',np.median(masses9[igood9d])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[igood9d])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses9[igood9d])*M_sun/M_jup)
#
print('COOL')
print('Mean mass',np.mean(masses9[icgood9d]))
print('Median mass',np.median(masses9[icgood9d]))
print('STDDEV mass',np.std(masses9[icgood9d]))
print('Mean mass (M_Jup)',np.mean(masses9[icgood9d])*M_sun/M_jup)
print('Median mass',np.median(masses9[icgood9d])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icgood9d])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses9[icoldgood9d]))
print('Median mass',np.median(masses9[icoldgood9d]))
print('STDDEV mass',np.std(masses9[icoldgood9d]))
print('Mean mass (M_Jup)',np.mean(masses9[icoldgood9d])*M_sun/M_jup)
print('Median mass',np.median(masses9[icoldgood9d])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icoldgood9d])*M_sun/M_jup)
#
# Out:
# Minimum is 4.454426324832145e-10
# Cool Minimum is 5.897779285720163e-10
# Cold Minimum is 1.08343216624394e-07
# Teff (hot):  1103.4947361993616
# Teff (cool):  1121.5262469391187
# HR8799d
# HOT
# Mean mass 0.006559976570215338
# Median mass 0.006477432306884857
# STDDEV mass 0.0005191192540446402
# Mean mass (M_Jup) 6.872005231938303
# Median mass 6.785534708240238
# STDDEV mass 0.5438114285334366
# MINIMUM mass 5.549714434652643
# COOL
# Mean mass 0.007191577540151005
# Median mass 0.007055224905546397
# STDDEV mass 0.0006494912345669653
# Mean mass (M_Jup) 7.533648627069017
# Median mass 7.390810309224129
# STDDEV mass 0.6803846194066118
# COLD
# Mean mass 0.012321313717631305
# Median mass 0.012321259560196751
# STDDEV mass 1.540582064255879e-05
# Mean mass (M_Jup) 12.907383345903638
# Median mass 12.907326612442837
# STDDEV mass 0.016138606430189103

# %%
#now compute chi2 etc. etc.
chi29e = ((stars9_logL - hrAloglume)/0.05)**2
chi2min9e=np.min(chi29e)
print('Minimum is',chi2min9e)
prob9e=np.exp((chi2min9e-chi29e)/2)
draw9e=np.random.uniform(size=size9)
igood9e=(prob9e>draw9e)
#
cool_chi29e = ((cool9_logL - hrAloglume)/0.05)**2
cool_chi2min9e=np.min(cool_chi29e)
print('Cool Minimum is',cool_chi2min9e)
cool_prob9e=np.exp((cool_chi2min9e-cool_chi29e)/2)
cool_draw9e=np.random.uniform(size=size9)
icgood9e=(cool_prob9e>cool_draw9e)
#
# although we do this for cold the fits are no good. see plot below
cold_chi29e = ((cold9_logL - hrAloglume)/0.05)**2
cold_chi2min9e=np.min(cold_chi29e)
print('Cold Minimum is',cold_chi2min9e)
cold_prob9e=np.exp((cold_chi2min9e-cold_chi29e)/2)
cold_draw9e=np.random.uniform(size=size9)
icoldgood9e=(cold_prob9e>cold_draw9e)
#
teff9ehot=CELLO_interp_logTeff(np.median(masses9[igood9e]),ages9[igood9e])
teff9ecool=CELLO_cool_interp_logTeff(np.median(masses9[icgood9e]),ages9[igood9e])
print("Teff (hot): ",10**np.median(teff9ehot))
print("Teff (cool): ",10**np.median(teff9ecool))
#
print("HR8799e")
print('HOT')
print('Mean mass',np.mean(masses9[igood9e]))
print('Median mass',np.median(masses9[igood9e]))
print('STDDEV mass',np.std(masses9[igood9e]))
print('Mean mass (M_Jup)',np.mean(masses9[igood9e])*M_sun/M_jup)
print('Median mass',np.median(masses9[igood9e])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[igood9e])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses9[igood9e])*M_sun/M_jup)
#
print('COOL')
print('Mean mass',np.mean(masses9[icgood9e]))
print('Median mass',np.median(masses9[icgood9e]))
print('STDDEV mass',np.std(masses9[icgood9e]))
print('Mean mass (M_Jup)',np.mean(masses9[icgood9e])*M_sun/M_jup)
print('Median mass',np.median(masses9[icgood9e])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icgood9e])*M_sun/M_jup)
#
print('COLD')
print('Mean mass',np.mean(masses9[icoldgood9e]))
print('Median mass',np.median(masses9[icoldgood9e]))
print('STDDEV mass',np.std(masses9[icoldgood9e]))
print('Mean mass (M_Jup)',np.mean(masses9[icoldgood9e])*M_sun/M_jup)
print('Median mass',np.median(masses9[icoldgood9e])*M_sun/M_jup)
print('STDDEV mass',np.std(masses9[icoldgood9e])*M_sun/M_jup)
#
# Out:
# Minimum is 5.993920021170508e-11
# Cool Minimum is 7.888408886159076e-12
# Cold Minimum is 9.82727848496473e-07
# Teff (hot):  1087.952696182965
# Teff (cool):  1084.205482052649
# HR8799e
# HOT
# Mean mass 0.0062429524289890044
# Median mass 0.006185483436952066
# STDDEV mass 0.00038935321041865255
# Mean mass (M_Jup) 6.539901674274743
# Median mass 6.479699140054549
# STDDEV mass 0.40787299625692486
# MINIMUM mass 5.527138453043931
# COOL
# Mean mass 0.006729139348558146
# Median mass 0.0066494929735665745
# STDDEV mass 0.00047941172872943894
# Mean mass (M_Jup) 7.049214324894383
# Median mass 6.965779529085497
# STDDEV mass 0.5022151943407238
# COLD
# Mean mass 0.012309135178549863
# Median mass 0.01230907407418546
# STDDEV mass 1.528913201526889e-05
# Mean mass (M_Jup) 12.894625528342972
# Median mass 12.89456151751803
# STDDEV mass 0.016016367448287137

# %%
#plt.plot(model012hot['col3']/1e6,model012hot['col12'],label='0.012')
plt.plot(model011hot['col3']/1e6,model011hot['col11'],'--',label='0.011')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'--',label='0.010')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'--',label='0.009')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'--',label='0.008')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'--',label='0.007')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'--',label='0.006')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'--',label='0.005')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'--',label='0.004')
plt.plot([30],hrAloglumb,'k.')
plt.plot([30],hrAloglumc,'k.')
plt.plot([30],hrAloglumd,'k.')
plt.plot([30],hrAloglume,'k.')
plt.xlim(10,100)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
plt.title('CELLO Hot Start and HR8799')
# Out:
# Text(0.5, 1.0, 'CELLO Hot Start and HR8799')

# %%
#plt.plot(model012cool['col3']/1e6,model012cool['col12'],label='0.012')
plt.plot(model011cool['col3']/1e6,model011cool['col11'],'--',label='0.011')
plt.plot(model010cool['col3']/1e6,model010cool['col12'],'--',label='0.010')
plt.plot(model009cool['col3']/1e6,model009cool['col12'],'--',label='0.009')
plt.plot(model008cool['col3']/1e6,model008cool['col12'],'--',label='0.008')
plt.plot(model007cool['col3']/1e6,model007cool['col12'],'--',label='0.007')
plt.plot(model006cool['col3']/1e6,model006cool['col12'],'--',label='0.006')
plt.plot(model005cool['col3']/1e6,model005cool['col12'],'--',label='0.005')
plt.plot(model004cool['col3']/1e6,model004cool['col12'],'--',label='0.004')
plt.plot([30],hrAloglumb,'k.')
plt.plot([30],hrAloglumc,'k.')
plt.plot([30],hrAloglumd,'k.')
plt.plot([30],hrAloglume,'k.')
plt.xlim(10,100)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-2)
plt.title('CELLO Cool Start and HR8799')
# Out:
# Text(0.5, 1.0, 'CELLO Cool Start and HR8799')

# %%
plt.plot(model012ucold['col3']/1e6,model012ucold['col12'],label='0.012')
plt.plot(model011ucold['col3']/1e6,model011ucold['col11'],'--',label='0.011')
plt.plot(model010ucold['col3']/1e6,model010ucold['col12'],'--',label='0.010')
plt.plot(model009ucold['col3']/1e6,model009ucold['col12'],'--',label='0.009')
plt.plot(model008ucold['col3']/1e6,model008ucold['col12'],'--',label='0.008')
plt.plot(model007ucold['col3']/1e6,model007ucold['col12'],'--',label='0.007')
plt.plot(model006ucold['col3']/1e6,model006ucold['col12'],'--',label='0.006')
plt.plot(model005ucold['col3']/1e6,model005ucold['col12'],'--',label='0.005')
plt.plot(model004ucold['col3']/1e6,model004ucold['col12'],'--',label='0.004')
plt.plot([30],hrAloglumb,'k.')
plt.plot([30],hrAloglumc,'k.')
plt.plot([30],hrAloglumd,'k.')
plt.plot([30],hrAloglume,'k.')
plt.xlim(10,100)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-8,-2)
plt.title('CELLO Cold Start and HR8799')
#plainly these models do not fit at all!!!
# Out:
# Text(0.5, 1.0, 'CELLO Cold Start and HR8799')

# %%
#plt.plot(model012hot['col3']/1e6,model012hot['col12'],'-',label='0.012 hot')
#plt.plot(model011hot['col3']/1e6,model011hot['col11'],'-',label='0.011 hot')
plt.plot(model011hot['col3']/1e6,model011hot['col12'],'-',color='C7',label='0.011 hot')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'-',color='C0',label='0.010 hot')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'-',color='C1',label='0.009 hot')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'-',color='C2',label='0.008 hot')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'-',color='C3',label='0.007 hot')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'-',color='C4',label='0.006 hot')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'-',color='C5',label='0.005 hot')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'-',color='C6',label='0.004 hot')
#plt.plot(model012cool['col3']/1e6,model012cool['col12'],'--',label='0.012 cool')
#plt.plot(model011cool['col3']/1e6,model011cool['col11'],'--',label='0.011 cool')
plt.plot(model011cool['col3']/1e6,model011cool['col12'],'--',color='C7',label='0.011 cool')
plt.plot(model010cool['col3']/1e6,model010cool['col12'],'--',color='C0',label='0.010 cool')
plt.plot(model009cool['col3']/1e6,model009cool['col12'],'--',color='C1',label='0.009 cool')
plt.plot(model008cool['col3']/1e6,model008cool['col12'],'--',color='C2',label='0.008 cool')
plt.plot(model007cool['col3']/1e6,model007cool['col12'],'--',color='C3',label='0.007 cool')
plt.plot(model006cool['col3']/1e6,model006cool['col12'],'--',color='C4',label='0.006 cool')
plt.plot(model005cool['col3']/1e6,model005cool['col12'],'--',color='C5',label='0.005 cool')
plt.plot(model004cool['col3']/1e6,model004cool['col12'],'--',color='C6',label='0.004 cool')
plt.plot([42],hrAloglumb,'k.')
plt.plot([42],hrAloglumc,'k.')
plt.plot([42],hrAloglumd,'k.')
plt.plot([42],hrAloglume,'k.')
plt.plot([20],hrAloglumb,'k.')
plt.plot([20],hrAloglumc,'k.')
plt.plot([20],hrAloglumd,'k.')
plt.plot([20],hrAloglume,'k.')
plt.plot([60],hrAloglumb,'k.')
plt.plot([60],hrAloglumc,'k.')
plt.plot([60],hrAloglumd,'k.')
plt.plot([60],hrAloglume,'k.')
plt.plot([90],hrAloglumb,'k.')
plt.plot([90],hrAloglumc,'k.')
plt.plot([90],hrAloglumd,'k.')
plt.plot([90],hrAloglume,'k.')
plt.xlim(10,100)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-3)
plt.title('CELLO Hot/Cool Start and HR8799')
#
plt.savefig('fig_HR8799.pdf')

# %%
#HR 8799e mass and luminosity
#
mass_planete = 9.6 * M_jup / M_sun
sigma_mass_planete = 1.9 * M_jup / M_sun
# Brandt et al. mass 9.6+/- 1.9
#draw ages
size99=2000000
ages99= np.random.uniform(2, 200, size99)
#we use the prior of the observed mass  
masses99=np.random.normal(mass_planete,sigma_mass_planete,size99)
#however, we cannot have masses less than 0.001 solar mass (much less negative)
# so we need to cut them off
itoolow = (masses99 < 0.00101)
masses99[itoolow] = 0.00101
stars99_logL=CELLO_interp_logL(masses99,ages99)
cool99_logL=CELLO_cool_interp_logL(masses99,ages99)
#now compute chi2 etc. etc.
chi99 = ((stars99_logL - hrAloglume)/0.05)**2
chi2min99=np.min(chi99)
print('Minimum is',chi2min99)
prob99=np.exp((chi2min99-chi99)/2)
draw99=np.random.uniform(size=size99)
igood99=(prob99>draw99)
#
cool_chi99 = ((cool99_logL - hrAloglume)/0.05)**2
cool_chi2min99=np.min(cool_chi99)
print('Cool Minimum is',cool_chi2min99)
cool_prob99=np.exp((cool_chi2min99-cool_chi99)/2)
cool_draw99=np.random.uniform(size=size99)
icgood99=(cool_prob99>cool_draw99)
#
# Out:
# Minimum is 3.157454274210722e-12
# Cool Minimum is 8.86574628719392e-11

# %%
mass_planete,sigma_mass_planete
# Out:
# (<Quantity 0.0091641>, <Quantity 0.00181373>)

# %%
np.min(cool99_logL)
# Out:
# -7.249333859960514

# %%
#
print("HR8799e MASS, LUMINOSITY CONSTRAINT")
print('HOT')
print('Mean mass',np.mean(masses99[igood99]))
print('Median mass',np.median(masses99[igood99]))
print('STDDEV mass',np.std(masses99[igood99]))
print('Mean mass (M_Jup)',np.mean(masses99[igood99])*M_sun/M_jup)
print('Median mass',np.median(masses99[igood99])*M_sun/M_jup)
print('STDDEV mass',np.std(masses99[igood99])*M_sun/M_jup)
print('MINIMUM mass',np.min(masses99[igood99])*M_sun/M_jup)
#
print('Mean AGE',np.mean(ages99[igood99]))
print('Median AGE',np.median(ages99[igood99]))
print('STDDEV AGE',np.std(ages99[igood99]))
#

print('COOL')
print('Mean mass',np.mean(masses99[icgood99]))
print('Median mass',np.median(masses99[icgood99]))
print('STDDEV mass',np.std(masses99[icgood99]))
print('Mean mass (M_Jup)',np.mean(masses99[icgood99])*M_sun/M_jup)
print('Median mass',np.median(masses99[icgood99])*M_sun/M_jup)
print('STDDEV mass',np.std(masses99[icgood99])*M_sun/M_jup)
#
print('Mean AGE',np.mean(ages99[icgood99]))
print('Median AGE',np.median(ages99[icgood99]))
print('STDDEV AGE',np.std(ages99[icgood99]))
#
# Out:
# HR8799e MASS, LUMINOSITY CONSTRAINT
# HOT
# Mean mass 0.009880969047539538
# Median mass 0.009951530264009679
# STDDEV mass 0.0016057453500347863
# Mean mass (M_Jup) 10.350962425630001
# Median mass 10.424879922676615
# STDDEV mass 1.6821234540228593
# MINIMUM mass 2.643626650946396
# Mean AGE 82.85036248519405
# Median AGE 71.46600563066505
# STDDEV AGE 39.539108368608716
# COOL
# Mean mass 0.009921673346524133
# Median mass 0.009976806797391283
# STDDEV mass 0.001623410854009174
# Mean mass (M_Jup) 10.393602845544693
# Median mass 10.451358747377347
# STDDEV mass 1.7006292267855254
# Mean AGE 78.68194392222176
# Median AGE 65.87328816599128
# STDDEV AGE 41.20057652327123

# %%
plt.plot(ages99[igood99],masses99[igood99],'k.',alpha=0.1)

# %%
#plt.plot(model012hot['col3']/1e6,model012hot['col12'],'-',label='0.012 hot')
#plt.plot(model011hot['col3']/1e6,model011hot['col11'],'-',label='0.011 hot')
plt.plot(model011hot['col3']/1e6,model011hot['col12'],'-',color='C7',label='0.011 hot')
plt.plot(model010hot['col3']/1e6,model010hot['col12'],'-',color='C0',label='0.010 hot')
plt.plot(model009hot['col3']/1e6,model009hot['col12'],'-',color='C1',label='0.009 hot')
plt.plot(model008hot['col3']/1e6,model008hot['col12'],'-',color='C2',label='0.008 hot')
plt.plot(model007hot['col3']/1e6,model007hot['col12'],'-',color='C3',label='0.007 hot')
plt.plot(model006hot['col3']/1e6,model006hot['col12'],'-',color='C4',label='0.006 hot')
plt.plot(model005hot['col3']/1e6,model005hot['col12'],'-',color='C5',label='0.005 hot')
plt.plot(model004hot['col3']/1e6,model004hot['col12'],'-',color='C6',label='0.004 hot')
#plt.plot(model012cool['col3']/1e6,model012cool['col12'],'--',label='0.012 cool')
#plt.plot(model011cool['col3']/1e6,model011cool['col11'],'--',label='0.011 cool')
plt.plot(model011cool['col3']/1e6,model011cool['col12'],'--',color='C7',label='0.011 cool')
plt.plot(model010cool['col3']/1e6,model010cool['col12'],'--',color='C0',label='0.010 cool')
plt.plot(model009cool['col3']/1e6,model009cool['col12'],'--',color='C1',label='0.009 cool')
plt.plot(model008cool['col3']/1e6,model008cool['col12'],'--',color='C2',label='0.008 cool')
plt.plot(model007cool['col3']/1e6,model007cool['col12'],'--',color='C3',label='0.007 cool')
plt.plot(model006cool['col3']/1e6,model006cool['col12'],'--',color='C4',label='0.006 cool')
plt.plot(model005cool['col3']/1e6,model005cool['col12'],'--',color='C5',label='0.005 cool')
plt.plot(model004cool['col3']/1e6,model004cool['col12'],'--',color='C6',label='0.004 cool')
plt.plot([30],hrAloglumb,'k.')
plt.plot([30],hrAloglumc,'k.')
plt.plot([30],hrAloglumd,'k.')
plt.plot([30],hrAloglume,'k.')
plt.plot([20],hrAloglumb,'k.')
plt.plot([20],hrAloglumc,'k.')
plt.plot([20],hrAloglumd,'k.')
plt.plot([20],hrAloglume,'k.')
plt.plot([60],hrAloglumb,'k.')
plt.plot([60],hrAloglumc,'k.')
plt.plot([60],hrAloglumd,'k.')
plt.plot([60],hrAloglume,'k.')
plt.plot([90],hrAloglumb,'k.')
plt.plot([90],hrAloglumc,'k.')
plt.plot([90],hrAloglumd,'k.')
plt.plot([90],hrAloglume,'k.')
plt.xlim(10,200)
plt.legend(ncol=2)
plt.xlabel('Age (Myr)')
plt.ylabel('log Luminosity (solar)')
plt.ylim(-5.5,-3)
plt.title('CELLO Hot/Cool Start and HR8799')
#
# Out:
# Text(0.5, 1.0, 'CELLO Hot/Cool Start and HR8799')

# %%
import emcee
# let's look at all the masses together.

# %%
#parameters are age, massb,massc,massd, masse 
#data is 
# lumb, lumc, lumd, lume, masse
#
# prior just enforcing within reasonable range
def log_prior(theta):
    age, mb, mc, md, me = theta
    if 2 < age < 100 and 0.00101 < mb < 0.025 and 0.00101 < mc < 0.025 and 0.00101 < md < 0.025 and 0.00101 < me < 0.025:
        #if no mass prior then:
        #return 0.0
        return -0.5 * ((me - 0.0091641)**2/ (0.00181373**2))
    return -np.inf

# %%
def log_likelihood(theta, y, yerr):
    age, mb, mc, md, me = theta
    modellum = CELLO_interp_logL([mb,mc,md,me],[age,age,age,age])
    sigma2 = yerr**2 
    return -0.5 * (np.sum((modellum-y)**2/sigma2))

# %%
y=np.array([hrAloglumb,hrAloglumc,hrAloglumd,hrAloglume])
yerr=np.array([0.05,0.05,0.05,0.05])

# %%
def log_probability(theta, y, yerr):
    lp = log_prior(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, y, yerr)

# %%
pos = np.array([60,0.007,0.009,0.009,0.009]) + [6,5e-4,5e-4,5e-4,5e-4] * np.random.randn(32,5)
nwalkers, ndim = pos.shape

# %%
sampler = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability, args=(y, yerr)
)
sampler.run_mcmc(pos, 90000, progress=True);
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 90000/90000 [01:04<00:00, 1385.82it/s]

# %%
fig, axes = plt.subplots(5, figsize=(10, 7), sharex=True)
samples = sampler.get_chain()
labels = ["age", "mb", "mc","md","me"]
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples))
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel("step number");

# %%
tau = sampler.get_autocorr_time()
print(tau)
# Out:
# [95.94716157 92.53661851 91.8076129  92.30655637 90.82515083]

# %%
flat_samples = sampler.get_chain(discard=300, thin=55, flat=True)
print(flat_samples.shape)
# Out:
# (52160, 5)

# %%
import corner

# %%
fig = corner.corner(
    flat_samples, labels=labels
);

# %%
flat_samples
# Out:
# array([[3.92382651e+01, 5.57069428e-03, 6.93595022e-03, 7.27604606e-03,
#         7.02196167e-03],
#        [4.96032953e+01, 6.68209661e-03, 8.20058734e-03, 8.04538442e-03,
#         7.82023724e-03],
#        [9.63348320e+01, 9.07042058e-03, 1.14905072e-02, 1.15319515e-02,
#         1.10149099e-02],
#        ...,
#        [6.42276462e+01, 7.78227238e-03, 8.88322430e-03, 9.48105962e-03,
#         9.08071998e-03],
#        [2.10199686e+01, 3.96039306e-03, 5.18295336e-03, 4.98117588e-03,
#         5.05036869e-03],
#        [6.35162901e+01, 7.11931775e-03, 9.42238916e-03, 1.05157409e-02,
#         9.66498171e-03]])

# %%
plt.plot(flat_samples[:,0],flat_samples[:,3]/flat_samples[:,4],'k.',alpha=0.02)

# %%
np.median(flat_samples[:,0])
# Out:
# 62.973656671398416

# %%
y
# Out:
# array([-4.98706676, -4.65737597, -4.62212405, -4.66253082])

# %%
new_samples=np.array([flat_samples[:,0],flat_samples[:,4],flat_samples[:,1]/flat_samples[:,4],flat_samples[:,3]/flat_samples[:,4]])
new_labels=['age (Myr)','Mass e','Mass b/ Mass e','Mass d/ Mass e']

# %%
new_samples
# Out:
# array([[3.92382651e+01, 4.96032953e+01, 9.63348320e+01, ...,
#         6.42276462e+01, 2.10199686e+01, 6.35162901e+01],
#        [7.02196167e-03, 7.82023724e-03, 1.10149099e-02, ...,
#         9.08071998e-03, 5.05036869e-03, 9.66498171e-03],
#        [7.93324507e-01, 8.54462135e-01, 8.23467523e-01, ...,
#         8.57010501e-01, 7.84178998e-01, 7.36609542e-01],
#        [1.03618425e+00, 1.02879033e+00, 1.04694016e+00, ...,
#         1.04408677e+00, 9.86299453e-01, 1.08802492e+00]])

# %%
new_samples
# Out:
# array([[3.92382651e+01, 4.96032953e+01, 9.63348320e+01, ...,
#         6.42276462e+01, 2.10199686e+01, 6.35162901e+01],
#        [7.02196167e-03, 7.82023724e-03, 1.10149099e-02, ...,
#         9.08071998e-03, 5.05036869e-03, 9.66498171e-03],
#        [7.93324507e-01, 8.54462135e-01, 8.23467523e-01, ...,
#         8.57010501e-01, 7.84178998e-01, 7.36609542e-01],
#        [1.03618425e+00, 1.02879033e+00, 1.04694016e+00, ...,
#         1.04408677e+00, 9.86299453e-01, 1.08802492e+00]])

# %%
np.median(flat_samples,axis=0)
# Out:
# array([6.29736567e+01, 7.34004340e-03, 9.44131864e-03, 9.81490129e-03,
#        9.35571627e-03])

# %%
ratiobe = flat_samples[:,1]/flat_samples[:,4]
ratioce = flat_samples[:,2]/flat_samples[:,4]
ratiode = flat_samples[:,3]/flat_samples[:,4]

# %%
plt.plot(flat_samples[:,0],ratioce,'k.',alpha=.05)

# %%
print("b/e",np.median(ratiobe),np.std(ratiobe))
print("c/e",np.median(ratioce),np.std(ratioce))
print("d/e",np.median(ratiode),np.std(ratiode))
print("age",np.median(flat_samples[:,0]),np.std(flat_samples[:,0]))
print("mass b",np.median(flat_samples[:,1]),np.std(flat_samples[:,1]))
print("mass c",np.median(flat_samples[:,2]),np.std(flat_samples[:,2]))
print("mass d",np.median(flat_samples[:,3]),np.std(flat_samples[:,3]))
print("mass e",np.median(flat_samples[:,4]),np.std(flat_samples[:,4]))
# Out:
# b/e 0.7936491916118964 0.05243447668971404
# c/e 1.0066211363503226 0.08014038241952397
# d/e 1.0408471125734782 0.08544347511886331
# age 62.973656671398416 13.359321968241227
# mass b 0.00734004339646098 0.0008617922120570293
# mass c 0.009441318635982996 0.001052697820325718
# mass d 0.009814901288928188 0.0010276343784967829
# mass e 0.009355716274183804 0.001002691008826759

# %%
plt.plot(flat_samples[:,0],flat_samples[:,4],'k.',alpha=.05)

# %%
#parameters are age, massb,massc,massd, masse 
#data is 
# lumb, lumc, lumd, lume, masse
#
# prior just enforcing within reasonable range
def log_prior_age_mass(theta):
    age, mb, mc, md, me = theta
    if 2 < age < 100 and 0.00101 < mb < 0.025 and 0.00101 < mc < 0.025 and 0.00101 < md < 0.025 and 0.00101 < me < 0.025:
        #if no mass prior then:
        #return 0.0
        return -0.5 * (((me - 0.0091641)**2/ (0.00181373**2))+((age-42)**2)/(5.0**2))
    return -np.inf

# %%
def log_probability_age_mass(theta, y, yerr):
    lp = log_prior_age_mass(theta)
    if not np.isfinite(lp):
        return -np.inf
    return lp + log_likelihood(theta, y, yerr)

# %%
pos = np.array([60,0.007,0.009,0.009,0.009]) + [8,5e-4,5e-4,5e-4,5e-4] * np.random.randn(55,5)
nwalkers, ndim = pos.shape

# %%
sampler2 = emcee.EnsembleSampler(
    nwalkers, ndim, log_probability_age_mass, args=(y, yerr)
)
sampler2.run_mcmc(pos, 60000, progress=True);
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 60000/60000 [01:11<00:00, 834.71it/s]

# %%
tau2 = sampler2.get_autocorr_time()
print(tau2)
# Out:
# [63.53774422 63.16611201 69.46004042 67.51362039 68.89755945]

# %%
flat_samples2 = sampler2.get_chain(discard=300, thin=33, flat=True)
print(flat_samples.shape)
# Out:
# (52160, 5)

# %%
np.median(flat_samples2,axis=0)
# Out:
# array([4.46828535e+01, 6.11698468e-03, 7.85984090e-03, 8.25625338e-03,
#        7.89780556e-03])

# %%
fig = corner.corner(
    flat_samples2, labels=labels
);

# %%
ratiobe2 = flat_samples2[:,1]/flat_samples2[:,4]
ratioce2 = flat_samples2[:,2]/flat_samples2[:,4]
ratiode2 = flat_samples2[:,3]/flat_samples2[:,4]

# %%
print("b/e",np.median(ratiobe),np.std(ratiobe))
print("c/e",np.median(ratioce),np.std(ratioce))
print("d/e",np.median(ratiode),np.std(ratiode))
print("age",np.median(flat_samples[:,0]),np.std(flat_samples[:,0]))
print("mass b",np.median(flat_samples2[:,1]),np.std(flat_samples2[:,1]))
print("mass c",np.median(flat_samples2[:,2]),np.std(flat_samples2[:,2]))
print("mass d",np.median(flat_samples2[:,3]),np.std(flat_samples2[:,3]))
print("mass e",np.median(flat_samples2[:,4]),np.std(flat_samples2[:,4]))
# Out:
# b/e 0.7936491916118964 0.05243447668971404
# c/e 1.0066211363503226 0.08014038241952397
# d/e 1.0408471125734782 0.08544347511886331
# age 62.973656671398416 13.359321968241227
# mass b 0.0061169846847057 0.0004044165725403195
# mass c 0.007859840904387811 0.0007328055719862466
# mass d 0.008256253375929128 0.0008203833343355554
# mass e 0.007897805555571309 0.0007127740797758504
