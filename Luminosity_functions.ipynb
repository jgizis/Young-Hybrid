# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii

# %%
def mass_powerlaw(size,m0,m1,alpha):
    #dN/dM ~ M**(-alpha)
    factor1= (m1**(1-alpha)-m0**(1-alpha))
    factor2 = m0**(1-alpha)
    return (factor1*np.random.rand(size)+factor2)**(1/(1-alpha))

# %%
dirname='/Users/gizis/data/Models/CELLO'

# %%
#Set up the hot start model names
hname030='{0}/{1}/0p030_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname025='{0}/{1}/0p025_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname020='{0}/{1}/0p020_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname019='{0}/{1}/0p019_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname018='{0}/{1}/0p018_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname017='{0}/{1}/0p017_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname016='{0}/{1}/0p016_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname015='{0}/{1}/0p015_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname014='{0}/{1}/0p014_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname013='{0}/{1}/0p013_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname012='{0}/{1}/0p012_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname011='{0}/{1}/0p011_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname010='{0}/{1}/0p010_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname009='{0}/{1}/0p009_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname008='{0}/{1}/0p008_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname007='{0}/{1}/0p007_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname006='{0}/{1}/0p006_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname005='{0}/{1}/0p005_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname004='{0}/{1}/0p004_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname003='{0}/{1}/0p003_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname002='{0}/{1}/0p002_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname001='{0}/{1}/0p001_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
# have some extra at finer mass scales:
hname0125='{0}/{1}/0p0125_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0135='{0}/{1}/0p0135_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0145='{0}/{1}/0p0145_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
hname0155='{0}/{1}/0p0155_CD_2021(noZ)_Dusty_ATMO20_hotstart_stru.txt'.format(dirname,'Hot_Start_evolution_models')
#

# %%
#  Read the Hot Start Models
model030hot=ascii.read(hname030)
model025hot=ascii.read(hname025)
model020hot=ascii.read(hname020)
model019hot=ascii.read(hname019)
model018hot=ascii.read(hname018)
model017hot=ascii.read(hname017)
model016hot=ascii.read(hname016)
model015hot=ascii.read(hname015)
model014hot=ascii.read(hname014)
model013hot=ascii.read(hname013)
model012hot=ascii.read(hname012)
model011hot=ascii.read(hname011)
model010hot=ascii.read(hname010)
model009hot=ascii.read(hname009)
model008hot=ascii.read(hname008)
model007hot=ascii.read(hname007)
model006hot=ascii.read(hname006)
model005hot=ascii.read(hname005)
model004hot=ascii.read(hname004)
model003hot=ascii.read(hname003)
model002hot=ascii.read(hname002)
model001hot=ascii.read(hname001)
#
model0155hot=ascii.read(hname0155)
model0145hot=ascii.read(hname0145)
model0135hot=ascii.read(hname0135)
model0125hot=ascii.read(hname0125)

# %%
allname='{0}/{1}/hot.all.txt'.format(dirname,'Hot_Start_evolution_models')
allhot=ascii.read(allname)

# %%
allhot
# Out:
# <Table length=16754>
#  col1     col2           col3           col4    col5    col6     col7     col8    col9  ...   col20    col21   col22      col23         col24      col25   col26   col27
# int64   float64        float64        float64   str1  float64  float64  float64 float64 ...  float64  float64 float64    float64       float64    float64 float64 float64
# ----- ----------- ------------------ ---------- ---- --------- -------- ------- ------- ... --------- ------- ------- ------------- ------------- ------- ------- -------
#     0        10.0                0.0 -2.883e-11    r  1.51e-39 -2.59158 3.96694 0.70801 ...   0.09524    7.28   12.19 3.9297035e-19  6.811811e-08   0.275 0.23909 0.83139
#     1        10.0               10.0 -2.002e-11    r 8.254e-40 -2.39296 4.04389 0.70801 ...   0.07452    7.54   12.47 4.5739779e-20 6.9347913e-08   0.275 0.21941 0.93525
# ...

# %%
from scipy.interpolate import LinearNDInterpolator

# %%
CELLO_interp_logTeff =  LinearNDInterpolator ((allhot['col13'],allhot['col3']/1e6),allhot['col11'],rescale=True)
CELLO_interp_logL =  LinearNDInterpolator ((allhot['col13'],allhot['col3']/1e6),allhot['col12'],rescale=True)

# %%
10.0**CELLO_interp_logTeff(0.020,20)
# Out:
# 2311.2466805051245

# %%
iq=((model020hot['col3']>19.5e6)&(model020hot['col3']<20.5e6))
10.0**model020hot['col11'][iq]
# Out:
# <Column name='col11' dtype='float64' length=4>
# 2319.4253529705265
# 2312.6776322353994
# 2306.5496100632354
# 2301.2695977198464

# %%
model020hot['col3'][iq]
# Out:
# <Column name='col3' dtype='float64' length=4>
# 19680185.182969518
# 19941776.662018307
#  20188691.88379256
# 20416182.022949897

# %%
#Let us make a sample drawn from a power-law mass distribution...
sample_size=10000
star_masses=mass_powerlaw(sample_size,0.002,0.03,0.5)

# %%
#... and a uniform distribution of ages
# from 5 Myr to 250 Myr
star_ages = np.random.uniform(low=5.0,high=250.0,size=sample_size)

# %%
plt.plot(star_ages,star_masses,'.',alpha=0.1)

# %%
plt.hist(star_masses)
# Out:
# (array([1969., 1357., 1206.,  989.,  901.,  809.,  768.,  704.,  666.,
#          631.]),
#  array([0.00200062, 0.00480045, 0.00760028, 0.01040012, 0.01319995,
#         0.01599979, 0.01879962, 0.02159946, 0.02439929, 0.02719912,
#         0.02999896]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(star_ages)
# Out:
# (array([1060.,  940.,  979.,  997., 1062.,  991.,  989., 1019.,  988.,
#          975.]),
#  array([  5.06026155,  29.55336424,  54.04646692,  78.53956961,
#         103.0326723 , 127.52577498, 152.01887767, 176.51198036,
#         201.00508304, 225.49818573, 249.99128842]),
#  <BarContainer object of 10 artists>)

# %%
star_logTeff=CELLO_interp_logTeff(star_masses,star_ages)
star_logL=CELLO_interp_logL(star_masses,star_ages)

# %%
plt.hist(10.0**star_logTeff,range=[500,1800],bins=13)
plt.xlim(500,1500)
# Out:
# (500.0, 1500.0)

# %%
plt.plot(star_ages,10.0**star_logTeff,'.',alpha=0.10)
plt.plot(model030hot['col3']/1e6,10.0**model030hot['col11'],'k')
plt.plot(model002hot['col3']/1e6,10.0**model002hot['col11'],'k')
plt.xlim(5,250)
plt.xlabel('Age (Myr)')
# Out:
# Text(0.5, 0, 'Age (Myr)')

# %% [markdown]
# The hybrid model creates an excess at 1100-1200K. Note, however, the lack of points for ~80-100Myr.  This is because the D- burning models (0.012 and higher) take 100Myr to reach the transition but the non-D-burning (0.011 and lower) reach it in less than 80 Myr.

# %%
plt.plot(star_ages,10.0**star_logTeff,'.',alpha=0.10)
plt.plot(model030hot['col3']/1e6,10.0**model030hot['col11'],'k')
plt.plot(model002hot['col3']/1e6,10.0**model002hot['col11'],'k')
plt.plot(model007hot['col3']/1e6,10.0**model007hot['col11'],color='C6',alpha=0.6,label='0.007-0.009')
plt.plot(model008hot['col3']/1e6,10.0**model008hot['col11'],color='C6',alpha=0.3)
plt.plot(model009hot['col3']/1e6,10.0**model009hot['col11'],color='C6',alpha=0.3)
plt.plot(model011hot['col3']/1e6,10.0**model011hot['col11'],color='C1',alpha=0.3,label='0.011')
plt.plot(model012hot['col3']/1e6,10.0**model012hot['col11'],color='C2',alpha=0.3,label='0.012')
plt.plot(model013hot['col3']/1e6,10.0**model013hot['col11'],color='C4',alpha=0.3,label='0.013-0.016')
plt.plot(model014hot['col3']/1e6,10.0**model014hot['col11'],color='C4',alpha=0.3)
plt.plot(model015hot['col3']/1e6,10.0**model015hot['col11'],color='C4',alpha=0.3)
plt.plot(model016hot['col3']/1e6,10.0**model016hot['col11'],color='C4',alpha=0.3)
plt.xlim(8,250)
plt.xlabel('Age (Myr)')
plt.ylabel('Effective Temperature (K)')
plt.legend()
plt.title('CELLO Hot Start, IMF alpha=0.5') 
plt.savefig('poster_lf.png')

# %% [markdown]
# Above shows a few tracks to aid in interpretation.

# %%
plt.plot(star_ages,star_logL,'.',alpha=0.10)
plt.plot(model030hot['col3']/1e6,model030hot['col12'],'k')
plt.plot(model002hot['col3']/1e6,model002hot['col12'],'k')
plt.xlim(10,250)
plt.xlabel('Age (Myr)')
plt.ylabel('log L (solar)')
# Out:
# Text(0, 0.5, 'log L (solar)')

# %%
star_ages_old = np.random.uniform(low=1000.0,high=10000.0,size=sample_size)

# %%
star_logTeff_old=CELLO_interp_logTeff(star_masses,star_ages_old)
star_logL_old=CELLO_interp_logL(star_masses,star_ages_old)

# %%
plt.plot(star_ages_old,10.0**star_logTeff_old,'.',alpha=0.10)
plt.plot(model030hot['col3']/1e6,10.0**model030hot['col11'],'k')
plt.plot(model002hot['col3']/1e6,10.0**model002hot['col11'],'k')
#plt.plot(model013hot['col3']/1e6,10.0**model013hot['col11'],'r',alpha=0.2)
plt.xlim(1000,10000)
plt.ylim(300,1100)
plt.xlabel('Age (Myr)')
#there seems to be a slight excess corresponding to the 0.013 track.
# Out:
# Text(0.5, 0, 'Age (Myr)')

# %%
plt.plot(star_ages_old,10.0**star_logTeff_old,'.',alpha=0.10)
plt.plot(model030hot['col3']/1e6,10.0**model030hot['col11'],'k')
plt.plot(model002hot['col3']/1e6,10.0**model002hot['col11'],'k')
#plt.plot(model013hot['col3']/1e6,10.0**model013hot['col11'],'r',alpha=0.2)
plt.xlim(4000,10000)
plt.ylim(200,700)
plt.xlabel('Age (Myr)')
#there seems to be a slight excess corresponding to the 0.013 track for first few Gyr.
# Out:
# Text(0.5, 0, 'Age (Myr)')

# %%
#below is some experimenting with the numpy gradient routine. It's not very succesful and will likely be deleted.

# %%
#masses_grid=np.linspace(0.002,0.020,19)
masses_grid=np.linspace(0.002,0.020,37)
ages_TWA=8.0*np.ones(37)
ages_BPMG=23.0*np.ones(37)
ages_50=50.0*np.ones(37)
ages_Pleiades=120.0*np.ones(37)
ages_old=5000.0*np.ones(37)
#masses_grid

# %%
star_logTeff_TWA=CELLO_interp_logTeff(masses_grid,ages_TWA)
star_logTeff_BPMG=CELLO_interp_logTeff(masses_grid,ages_BPMG)
star_logTeff_50=CELLO_interp_logTeff(masses_grid,ages_50)
star_logTeff_Pleiades=CELLO_interp_logTeff(masses_grid,ages_Pleiades)
star_logTeff_old=CELLO_interp_logTeff(masses_grid,ages_old)

# %%
10.0**star_logTeff_BPMG
# Out:
# array([ 557.48267729,  628.55099761,  707.34133312,  775.45117222,
#         850.64532964,  933.9789965 , 1025.02986928, 1077.09082835,
#        1129.06318804, 1146.20351986, 1163.45057476, 1176.1992407 ,
#        1188.64554142, 1212.09225438, 1232.85535213, 1282.74574294,
#        1335.45866384, 1387.72661302, 1441.86734398, 1514.49924992,
#        1590.27536922, 1674.69992492, 1785.9270612 , 1896.77537909,
#        1982.91418977, 2052.73393744, 2108.73596627, 2152.36770455,
#        2185.12351258, 2207.86307208, 2215.17095228, 2214.80896038,
#        2214.18322218, 2218.69207424, 2222.50644276, 2233.08036911,
#        2243.30315625])

# %%
dTdm_TWA=np.gradient(10**star_logTeff_TWA,masses_grid)
dTdm_BPMG=np.gradient(10**star_logTeff_BPMG,masses_grid)
dTdm_50=np.gradient(10**star_logTeff_50,masses_grid)
dTdm_Pleiades=np.gradient(10**star_logTeff_Pleiades,masses_grid)
dTdm_old=np.gradient(10**star_logTeff_old,masses_grid)

# %%
plt.plot(masses_grid,10.0**star_logTeff_TWA,label='TWA')
plt.plot(masses_grid,10.0**star_logTeff_BPMG,label='BPMG')
plt.plot(masses_grid,10.0**star_logTeff_50,label='50 Myr')
plt.plot(masses_grid,10.0**star_logTeff_Pleiades,label='Plieades')
plt.plot(masses_grid,10.0**star_logTeff_old,label='5 Gyr')
plt.legend()

# %%
plt.plot(masses_grid,dTdm_TWA,label='TWA')
plt.plot(masses_grid,dTdm_BPMG,label='BPMG')
plt.plot(masses_grid,dTdm_50,label='50 Myr')
plt.plot(masses_grid,dTdm_Pleiades,label='Plieades')

# %%
plt.plot(10**star_logTeff_TWA,dTdm_TWA,label='TWA')
plt.plot(10**star_logTeff_BPMG,dTdm_BPMG,label='BPMG')
plt.plot(10**star_logTeff_50,dTdm_50,label='50 Myr')
plt.plot(10**star_logTeff_Pleiades,dTdm_Pleiades,label='Plieades')
plt.legend()

# %%
#Numerical derivatives are not very well defined, plus we aren't evebn making use of all of the models.  
#furthermore, the non-monotonic values are a problem!

# %%
masses_grid
# Out:
# array([0.002 , 0.0025, 0.003 , 0.0035, 0.004 , 0.0045, 0.005 , 0.0055,
#        0.006 , 0.0065, 0.007 , 0.0075, 0.008 , 0.0085, 0.009 , 0.0095,
#        0.01  , 0.0105, 0.011 , 0.0115, 0.012 , 0.0125, 0.013 , 0.0135,
#        0.014 , 0.0145, 0.015 , 0.0155, 0.016 , 0.0165, 0.017 , 0.0175,
#        0.018 , 0.0185, 0.019 , 0.0195, 0.02  ])
